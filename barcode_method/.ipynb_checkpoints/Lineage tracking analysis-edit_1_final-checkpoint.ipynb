# %%
import numpy as np
import math
import scipy
from matplotlib import pyplot as plt
# %pylab inline
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 10, 10
plt.rc("font", size=23)
from operator import itemgetter
import pandas as pd
import multiprocessing

from multiprocessing import Process

plt.rc('xtick', color='k', labelsize='medium', direction='in')
plt.rc('xtick.major', size=8, pad=12)
plt.rc('xtick.minor', size=8, pad=12)

plt.rc('ytick', color='k', labelsize='medium', direction='in')
plt.rc('ytick.major', size=8, pad=12)
plt.rc('ytick.minor', size=8, pad=12)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# This code is a generalization in Python of the code for barcode (BC) lineage tracking analysis from *Blundell and Levy, Nature 2015*. It considers more models than the two originally written which were either the lineage is neutral or a mutant arises in a neutral background.
#
# As this code was designed for analyzing lineage tracking in changing environments, the monoclonal population hypothesis doesn't hold anymore at the interface of two environments (actually because of standing genetic variation even at the beginning of the first environment this hypothesis doesn't hold). So other models have been added:
# - a non neutral mutant exists already at the beginning of the environment
# - a non neutral mutant exists already at the beginning of the environment and another mutant rises in that context.
#
# Also because of high standing genetic variation, longer timescale of adaptation and inhomogeneity in the distribution of BC at the interface of environments, we cannot use the hypothesis of neutrally exponentially declining lineages to calculate the mean population fitness: instead we need to have an a priori on the fitness of certain lineages (remeasured lineages) and then compute the population mean fitness.
#
#
# As a showcase of how the code works and also how the data looks like I use simulated data from my owon data simulator (code in another notebook, eventhough way less commented)

# %%
adresse='bc02_cluster_forPyFit.csv'#address where your lineage tracking data is
 
c=1.75 #The noise in the birth death process(I didn't try to re estimate it and took it from Blundell et al.)
#If you have the experimental set up for it, you should try to estimate it.
N_e=3*10**8 #The effective population size . Here it's the bottleneck size times the passage time 
N_final=3*10**8 #The population size you want to be rescaled to
g=1 #Passage time in generation
adresse_cloneInfo='/Data_simu/fitness_for_mean_fitness.csv'#address where your fitness remeasurement data is

# %% [markdown]
# For the compile_data to work your lineage tracking data file should be in a csv format. You might need to change a little the code below because my BC names here are numbers and I put it inthe index of the data frame... The time is calculated as g generations separating two data points. You should manually change this if it is not the case for your application.

# %%
def compile_data(adresse,N_final,g):
    df=pd.read_csv(adresse)
    keep_tot=[]
    for v in df.columns:
        tot=df[v].sum()
        keep_tot.append(tot)
        print(f'Population total time point {v} = {tot}')
    dico={i:np.round(np.array(df.iloc[i-1])/np.array(keep_tot)*N_final) for i in df.index}
    #just realize that this dico should have your BC name as key and the rescaled time serie as a value
    #you change whatever you need to, in this code, for it to work like that with your data.
    return list(df.index)[0],[int(v)*g for v in list(df.columns)],dico
## I had problems with pandas to assign the right index... check if the index name actually link well your BC name...

# %% [markdown]
# For the compile_clone_info to work each line should contain a BC and a fitness per cycle separated by '\t'

# %%
def compile_clone_info(adresse_cloneInfo,g):
    rem={}
    df=pd.read_csv(adresse_cloneInfo)
    df.index=df.BC###that's because i saved the name of the bc in the first colums, instead of the index...still don't know why it does that.
    print(df.head())
    for i in df.index:
        rem[i]=float(df.fitness[i])/g
    #changing fitness per cycle to fitness per generation, as you probably need to do if you using Atish Agarwala
    #code for fitness remeasrument
    return rem

# %%
[ssi,tt,data_dict]=compile_data(adresse,N_final,g) #ssi: one of the barcode, tt: time series (you might need to manually
# change that to take into account missing time points), data_dict: dictionnary linking a barcode to its time series
# Out:
# Population total time point 237 = 5235603
# Population total time point 8 = 234539
# Population total time point 50 = 2081399
# Population total time point 45 = 589441
# Population total time point 102 = 723556
# Population total time point 2 = 214217
# Population total time point 1 = 99207

# %%
tt
# Out:
# [237, 8, 50, 45, 102, 2, 1]

# %%
rem=compile_clone_info(adresse_cloneInfo,g) #Fitness remeasurement dictionnary already converted in fitness per generation
# Out:
#         Unnamed: 0      BC  fitness
# BC
# 60343            0   60343      0.0
# 121372           1  121372      0.0
# 393097           2  393097      0.0
# 283426           3  283426      0.0
# 243426           4  243426      0.0

# %%
zoom=[[data_dict[s][-1],s] for s in data_dict.keys()]
sortt=sorted(zoom,key=itemgetter(0),reverse=True)
list_ordered=[sortt[i][1] for i in range(len(sortt))]#ordering the BC according to their frequency in the population 
#at the last time point : this way we can focus on a subset of barcode that have probably been selected since they are 
#in the top most representated at the end of the environment.

tot_pop=[]

for i in range(len(data_dict[ssi])):
    tot_pop.append(sum([data_dict[s][i] for s in data_dict.keys()]))
print('this is new pop size',tot_pop)

generation=[tt[i+1]-tt[i] for i in range(len(tt)-1)]#retrieving passage time between two time points

timepoint=np.arange(len(data_dict[ssi]))

R_t=tot_pop
# Out:
# this is new pop size [299994179.0, 299990475.0, 299998539.0, 300007119.0, 300000275.0, 299999911.0, 300000026.0]

# %% [markdown]
# All the conditional probability functions that go through ML have the same form as describe in *Blundell and Levy, Nature 2015*, they just use rescaled parameters to broaden what kind of model this conditional probability function can offer.

# %%
#Conditional probability for max likelihood to determine mean fitness

def low_abundance_conditional_probability(x,r_t,totit,totitT,r_tT,T,s):
    s_bar=x[0]
    kappa=x[1]
    result=[]
    for i in range(len(r_t)):
        result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
                                       (4*math.pi*kappa*(float(r_tT[i])**(3./2))))\
        *np.exp(-((np.sqrt(float(r_tT[i]))-np.sqrt(float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar))))**2)/kappa)))
    return -sum(result)
#Bounded Nelder_Mead algorithm for minimizing the minus likelihood function : you can probably find one already 
#coded in scipy but I had difficulties to make the scipy one worked with bounds so I recoded it.
#Basically whenever it goes outside the bounds, the simplex function takes a big penalty : 10**9
def Nelder_Mead3(func,arguments,alpha,rho,gamma,sigma,bounds,delta,maxiter):
    dimension=len(arguments[0])+1
    
    dimensions=100*len(arguments[0])
    np.random.seed()
    
    simplex=list()
    constant_arg=[arguments[i] for i in range(1,len(arguments))]
    funquie=list()
    for k in range(dimensions):
        waiting=list()
        for p in range(len(arguments[0])):
            waiting.append(np.random.uniform(bounds[p][0],bounds[p][1]))
        args=[waiting]+constant_arg
        plouf=func(*args)
        simplex.append([waiting,plouf])
        funquie.append(plouf)
        
    when_to_stop=False
    iter_count=0
    
    while when_to_stop==False:
        simplex=sorted(simplex,key=itemgetter(1))
        m=[np.mean([simplex[i][0][j] for i in range(dimension)]) for j in range(dimension-1)]
        r=[m[i]+alpha*(m[i]-simplex[dimension-1][0][i]) for i in range(dimension-1)]
        args=[simplex[dimension-1][0]]+constant_arg
        plus=func(*args)
        args=[simplex[0][0]]+constant_arg
        minus=func(*args)
        args=[r]+constant_arg
        ok_bounds=0
        for i in range(dimension-1):
            if r[i]>=bounds[i][0] and r[i]<=bounds[i][1]:
                ok_bounds=0
            else:
                ok_bounds=1
                break
        if ok_bounds==0:
            middle=func(*args)
        else:
            middle=10**9
        
        
        if middle>minus and middle<plus:
            simplex[dimension-1]=[r,middle]
        else:
            if minus>middle:
                e=[r[i]+gamma*(r[i]-m[i]) for i in range(dimension-1)]
                args=[e]+constant_arg
                ok_bounds=0
                for i in range(dimension-1):
                    if e[i]>=bounds[i][0] and e[i]<=bounds[i][1]:
                        ok_bounds=0
                    else:
                        ok_bounds=1
                        break
                if ok_bounds==0:
                    func_e=func(*args)
                else:
                    func_e=10**9
                if func_e<middle:
                    simplex[dimension-1]=[e,func_e]
                else:
                    simplex[dimension-1]=[r,middle]
            else:
                b=True
                args=[simplex[dimension-2][0]]+constant_arg
                func_n_1=func(*args)
                if middle>=func_n_1:
                    c=[rho*r[i]+(1-rho)*m[i] for i in range(dimension-1)]
                    args=[c]+constant_arg
                    ok_bounds=0
                    for i in range(dimension-1):
                        if c[i]>=bounds[i][0] and c[i]<=bounds[i][1]:
                            ok_bounds=0
                        else:
                            ok_bounds=1
                            break
                    if ok_bounds==0:
                        func_c=func(*args)
                    else:
                        func_c=10**9
                    
                    #func_c=func(*args)
                    if func_c<=middle:
                        simplex[dimension-1]=[c,func_c]
                        b=False
                if b==True:
                    simplex2=[simplex[q] for q in range(len(simplex))]
                    for i in range(1,dimension):
                        simplex2[i][0]=[simplex[0][0][j]+sigma*(simplex[i][0][j]-simplex[0][0][j]) for j in range(dimension-1)] 
                        args=[simplex2[i][0]]+constant_arg
                        simplex2[i][1]=func(*args)
                    simplex=simplex2
        iter_count+=1
        if iter_count==maxiter:
            when_to_stop=True
            #print('Maxiter')
        if abs(simplex[0][1]-simplex[dimension-1][1])<delta:
            when_to_stop=True
            
    return simplex[0]

# %%
def Nelder_Mead3_list(i,mouff,func,arguments,alpha,rho,gamma,sigma,bounds,delta,maxiter):
    mouff[i]=Nelder_Mead3(func,arguments,alpha,rho,gamma,sigma,bounds,delta,maxiter)

# %%
remeasured=data_dict.keys()&rem.keys()
rem_neutral=[s for s in remeasured if abs(rem[s])==0] # taking only the lineages that have a neutral remeasured fitness,
#you should put an uppper bound to what you consider neutral instead of putting 0 like me here
print('total remeasured',len(data_dict.keys()&rem.keys()),'neutral remeasured',len(rem_neutral))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8b2a858acfde> in <module>
# ----> 1 remeasured=data_dict.keys()&rem.keys()
#       2 rem_neutral=[s for s in remeasured if abs(rem[s])==0] # taking only the lineages that have a neutral remeasured fitness,
#       3 #you should put an uppper bound to what you consider neutral instead of putting 0 like me here
#       4 print('total remeasured',len(data_dict.keys()&rem.keys()),'neutral remeasured',len(rem_neutral))
#
# NameError: name 'rem' is not defined

# %%
boundaries_mean=[[-0.1,0.2],[0.01,4]] # Boundaries for the mean fitness and kappa(experimental noise)
thre_pop_mean=10 # One more constrain on which of the neutral lineage you want to do the fit on, here those lineages 
# should be at least 10 in size alonf their time serie: you changes that to want works for you

# %% [markdown]
# neutral=real_adaptive1.keys()&real_adaptive.keys()
# micho=[s for s in neutral if real_adaptive1[s][0]==0  and real_adaptive[s][1]>90]
# mim=micho[0:500]
# dd=pd.DataFrame([[s,real_adaptive1[s][0]] for s in mim],columns=['BC',"fitness"])
# dd.to_csv(adresse_cloneInfo)

# %%
#plotting the lineages that will be used
cou=0
for s in rem_neutral:
    if min(data_dict[s])>thre_pop_mean:
        plt.plot(tt,data_dict[s])
        cou+=1
print(f'Number of lineages that will be used for mean pop fitness estimation = {cou}')
plt.yscale('log')
plt.xlabel('Generations')
plt.ylabel('Log10 rescaled lineage size')
plt.show()
# Out:
# Number of lineages that will be used for mean pop fitness estimation = 445

# %%
#Code for actually proceeding to the maximization of the loglikelihood for 
#esimation of the population mean fitness. It is done using the knowledge of some 
#neutral lineage barcode.0 I don't give the other option here, like I did in the paper,
#because I trully believe that this is how you should design your experiment
def mean_fitness_known_lineages(thre_pop_mean,boundaries_mean,mim,generation):    
    mean_kappa_k=[]
    mean_fitness_k=[]
    for i in range(1,len(data_dict[ssi])):
        #just a bunch of lien to parse your input so it will feed the log liklihood function
        arg1=[data_dict[s][i-1] for s in mim if  data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        arg2=[tot_pop[i-1] for s in mim if  data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        arg3=[tot_pop[i] for s in mim if  data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        arg4=[data_dict[s][i] for s in mim if  data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        arg5=[generation[i-1] for s in mim if data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        arg6=[rem[s] for s in mim if data_dict[s][i-1]>thre_pop_mean and data_dict[s][i]>thre_pop_mean]
        print('Number of lineages to fit for time point '+str(i-1)+' is',len(arg6))
        argumentes=[[0,0],arg1,arg2,arg3,arg4,arg5,arg6]
        
        # all along the code here , I use muiltiprocessing to parallelized computation when possible
        # Here, as Nelder Mead is stochastic at it's beginning and the landscape is probably rugged
        # I proceed to the ML 10 times in parallel and finally only take the best.
        pro_list=[]
        manager = multiprocessing.Manager()
        mouff = manager.dict()
        for k in range(10):#(please work with the number of workers you can afford)
            p = Process(target=Nelder_Mead3_list, args=(k,mouff,low_abundance_conditional_probability,argumentes,1,0.5,2,0.5,boundaries_mean,10**-6,1000))
            pro_list.append(p)


        for p in pro_list:
            p.start()

        for p in pro_list:
            p.join()
        [estimate,fval]=sorted(mouff.values(),key=itemgetter(1))[0]
        mean_kappa_k.append(estimate[1]) 
        mean_fitness_k.append(estimate[0])
        print('population mean fitness and kappa at time point '+str(i-1)+' are',estimate,'Log-Likelihood is',-fval)
        print()
        
        
        
    provi=mean_fitness_k
    
    mean_fitness_k=provi+[2*provi[len(provi)-1]-provi[len(provi)-2] +0.5*((provi[len(provi)-1]-provi[len(provi)-2])-(provi[len(provi)-2]-provi[len(provi)-3]))]        
    #here we calculate the last bit of mean fitness using first and second derivative 

    smooth_fitness_k=list()
    smooth=mean_fitness_k[0]
    for i in range(len(mean_fitness_k)-1):
        slopes=(mean_fitness_k[i+1]-mean_fitness_k[i])/generation[i]
        for j in range(int(generation[i])):
            smooth+=slopes
            smooth_fitness_k.append(smooth)
        smooth=mean_fitness_k[i+1]

    smooth_fitness_cut_k=list()
    ploof=0
    for i in range(len(generation)):
        gallile=list()
        for j in range(int(generation[i])):
            gallile.append(smooth_fitness_k[ploof+j])

        ploof+=int(generation[i])
        smooth_fitness_cut_k.append(gallile)


    boodoo=0
    for i in range(len(smooth_fitness_cut_k)):
        boodoo+=len(smooth_fitness_cut_k[i])



    pylab.rcParams['figure.figsize'] = 5, 5
    plt.rc("font", size=23)

    
    x=np.linspace(0,generation[0]*len(generation),generation[0]*len(generation))

    plt.plot(tt,mean_fitness_k,\
             'bo',markersize=20)

    plt.plot(x,smooth_fitness_k,\
             'y',linewidth=5)
    plt.xlabel('Generations')
    plt.ylabel('Estimated population \n mean fitness')

    plt.show()
    
    return mean_kappa_k,mean_fitness_k,smooth_fitness_cut_k,smooth_fitness_k
# the ML was giving us pop mean fitness every 8 generations, the smooth_fitness fills
# the gap between two ML just by subdividing the change between the 2 ML estimated points 
# into , here 8 pieces (linear approx)

# %%
[mean_kappa_k,mean_fitness_k,smooth_fitness_cut_k,smooth_fitness_k]=\
mean_fitness_known_lineages(thre_pop_mean,boundaries_mean,rem_neutral,generation)
# Out:
# Number of lineages to fit for time point 0 is 500
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 0 are [-0.0003215626040324655, 1.1321303634589894] Log-Likelihood is -1958.7872544874003
#
# Number of lineages to fit for time point 1 is 499
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 1 are [-0.0036428945402558676, 1.2257052608822634] Log-Likelihood is -1982.2319809322858
#
# Number of lineages to fit for time point 2 is 499
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 2 are [-5.551699819244839e-05, 1.2390065749602712] Log-Likelihood is -1980.5201186383547
#
# Number of lineages to fit for time point 3 is 499
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 3 are [-0.002358477326984205, 1.158101873670869] Log-Likelihood is -1967.1495504729703
#
# Number of lineages to fit for time point 4 is 499
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 4 are [-0.0012982106949955773, 1.1159085554511237] Log-Likelihood is -1954.7279568643028
#
# Number of lineages to fit for time point 5 is 498
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 5 are [-0.0023131936594945187, 1.1515895754038958] Log-Likelihood is -1967.5875108561531
#
# Number of lineages to fit for time point 6 is 496
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 6 are [0.0010588272416974897, 1.1787757996827433] Log-Likelihood is -1961.748376098667
#
# Number of lineages to fit for time point 7 is 496
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 7 are [0.0020190325060226878, 1.187525978782377] Log-Likelihood is -1951.5923495555926
#
# Number of lineages to fit for time point 8 is 496
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 8 are [0.010105247656478158, 1.153323847696855] Log-Likelihood is -1933.9011373894805
#
# Number of lineages to fit for time point 9 is 493
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 9 are [0.02027648994338934, 0.9091257702377442] Log-Likelihood is -1822.5338358368067
#
# Number of lineages to fit for time point 10 is 481
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 10 are [0.04041310531426802, 0.8944416950979128] Log-Likelihood is -1704.3143704356562
#
# Number of lineages to fit for time point 11 is 448
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# <ipython-input-9-25e421417a35>:8: RuntimeWarning: divide by zero encountered in log
#   result.append(np.log(np.sqrt((float(r_t[i]*totitT[i])/totit[i]*np.exp(T[i]*(s[i]-s_bar)))**(1./2)/\
# population mean fitness and kappa at time point 11 are [0.061554036539915, 0.7922858843264253] Log-Likelihood is -1461.7820013117212

# %%
mean_kappa=mean_kappa_k
mean_fitness=mean_fitness_k
smooth_fitness=smooth_fitness_k
smooth_fitness_cut=smooth_fitness_cut_k

# %% [markdown]
# # Models definition

# %%
#The core set of functions that calculate the ML for different model
s_0=smooth_fitness[0]

stop=0
def neutral_hypothesis_probability1(r_t,totit,totitT,r_tT,smoothie,kappa,s1,x):
    
    ending=int(sum([generation[i] for i in range(x)]))
    zumo=int(generation[x])
    
    T_s_bar=sum([s1-smoothie[i] for i in range(ending+zumo)])#the integral
    #of the mutant fitness minus the pop mean fitness, over time
    
    result=np.log(np.sqrt((float(r_t*totitT)/totit*np.exp(T_s_bar))**(1./2)/\
                                       (4*math.pi*kappa*(float(r_tT)**(3./2)))))\
    -((np.sqrt(float(r_tT))-np.sqrt(float(r_t*totitT)/totit*np.exp(T_s_bar)))**2)/kappa
    #print(result)
    return result

def log_likelihood_neutral_hypothesis1(data,s1):
    aa=list()
    for i in range(len(timepoint)-1-stop):
        
        aa.append(neutral_hypothesis_probability1(data[0],tot_pop[0],tot_pop[i+1],data[i+1],smooth_fitness,mean_kappa[i],s1,i))
    
    aa.append(np.log(np.sqrt((data[0])**(1./2)/(4*math.pi*2*(data[0])**(3./2))))\
                         -(np.sqrt(data[0])-np.sqrt(data[0]))**2/2)
    log_like=sum(aa)
    
    return log_like

        
        
def adaptive_hypothesis_probability1(key,r_t,r_tT,smoothie,x,kappa,s,s1,tau,Rt,ouft,ouftT):
    
    
    found=False
    
    ending=int(sum([generation[i] for i in range(x)]))
    if tau<=0:# if your mutant appeared from before
        found=True
        tau_int=int(tau)
        za=0
    
    
    if tau>0 and tau<ending:#if your your mutant appeard before or within the period of time you are looking at
        found=True
        tau_int=int(tau)
        za=int(tau/generation[0])
    zumo=int(generation[x])
    
    if found==True:#either you have a non neutral ancestor or rising mutant
        
        s_anc=0
        s_mut=s
        cc=c
        if tau_int>=0:# rescale the lineage size taking into account when the mutant arised
            N=data_dict[key][za]/tot_pop[za]*N_e*np.exp(sum([s1-smoothie[i] for i in range(za*generation[0],tau_int)]))
        else:
            N=data_dict[key][za]/tot_pop[za]*N_e
        #estimate the mean fitness of the lineage due to the rising mutant (the fitness of the rising mutant)
        # is relative to the ancestor, it is only when everything is done that you have to add the fitness of
        # of the mutant s to the fitness of its ancestor s1
        delta=1
        x_f=[cc/(s_mut-s_anc)*1./N]
        s_bar=[x_f[0]*(s_mut-s_anc)+s_anc]
        for i in range (1,ending+zumo-tau_int):
            x_f.append(x_f[i-1]*np.exp((s_mut-s_bar[i-1])*delta))
            s_bar.append(x_f[i]*(s_mut-s_anc)+s_anc)    
        
        T_s=sum([s for i in range(ending-tau_int,ending+zumo-tau_int)])#integration for neutral clones that are part of the lineage
        T_s0=sum([s1-smoothie[i] for i in range(ending,ending+zumo)])#integration for ancestral clones that are part of the lineage
        
        if tau_int>=0:
            T_s_0=sum([s_bar[i]+s1-smoothie[i+tau_int] for i in range(ending-tau_int)])#integration for rising mutant (note how s_bar and s1 are added)
            
        else:#if the mutant appeared before the experiment
            T_s_0=sum([s_bar[i-tau_int]+s1-smoothie[i] for i in range(ending)]+[s_bar[i]+s1-smoothie[0] for i in range(0,-tau_int)])
            
        New_tot=N*Rt*np.exp(T_s_0)/(N_e)
        x_f[ending-tau_int]*=New_tot
        
        mean_r_tT=((x_f[ending-tau_int])*np.exp(T_s)+\
                       (New_tot-x_f[ending-tau_int]))*np.exp(T_s0)
        
        result=np.log(np.sqrt((mean_r_tT*ouftT/ouft)**(1./2)/(4*math.pi*kappa*(r_tT)**(3./2))))\
            -(np.sqrt(r_tT)-np.sqrt(mean_r_tT*ouftT/ouft))**2/kappa
        
            
    else:#or your lineage decrease as neutral
        
        result=neutral_hypothesis_probability1(data_dict[key][0],tot_pop[0],ouftT,r_tT,smooth_fitness,kappa,s1,x)
        
    return result







def log_likelihood_adaptive_hypothesis1(key,data,s,s1,tau):
    
                
    log_like=sum([adaptive_hypothesis_probability1(key,data[i],data[i+1],smooth_fitness,i,mean_kappa[i],\
                                                         s,s1,tau,R_t[i],tot_pop[i],tot_pop[i+1])for i in range(len(timepoint)-1-stop)\
                 ])
    
    
    # Blundell add a point to the max likelihood for t0, so I followed
    if tau<0 :
    
        s_anc=0
        s_mut=s
        cc=c
        N=data_dict[key][0]/tot_pop[0]*N_e
        
        delta=1
        x_f=[cc/(s_mut-s_anc)*1./N]
        s_bar=[x_f[0]*(s_mut-s_anc)+s_anc]
        for i in range (1,int(abs(tau))):
            x_f.append(x_f[i-1]*np.exp((s_mut-s_bar[i-1])*delta))
            s_bar.append(x_f[i]*(s_mut-s_anc)+s_anc)
        
        T_s=(s)*abs(tau)
        T_s0=(s1-s_0)*abs(tau)
        if (x_f[-1:][0])<=1:
            mean_r_tT=((x_f[-1:][0])*data[0]*np.exp(T_s)+(data[0]-((1-x_f[-1:][0])*data[0])))*np.exp(T_s0)
        else:
            mean_r_tT=((x_f[-1:][0])*data[0]*np.exp(T_s))*np.exp(T_s0)
        
    else:
        mean_r_tT=data[0]
        
        
    log_like+=np.log(np.sqrt((mean_r_tT)**(1./2)\
                                 /(4*math.pi*2*(data[0])**(3./2))))\
                                -(np.sqrt(data[0])-np.sqrt(mean_r_tT))**2/2#-np.log(np.sqrt(data[0]*math.pi*2))
    
    return log_like

# %%
zoom=[[data_dict[s][-1],s] for s in data_dict.keys() if min(data_dict[s])>10] # take only lineages with enought read

sortt=sorted(zoom,key=itemgetter(0),reverse=True) #order them in terms of their size at the end of measurement

list_ordered=[sortt[i][1] for i in range(len(sortt))]

mean_exp=0.1 #mean of the prior for the exponential DFE

mut_rate=10**-5

delta_s=0.01

# %%
from scipy import optimize
vr101=list_ordered[:1000] # Fit only the top 1000 lineages at the end of the experiment
vr111=vr101
#model name stands for the variable parameter: 010 means only ancestral mutant is estimated, 101 means that
#rising mutant fitness and establishement time is being estimated, and 111 means all of the above are estimated together
def model010(x,key,data):
    
    s1=x
    
    
    return -(np.log(1./mean_exp*np.exp(-1./mean_exp*s1)*0.001)+log_likelihood_neutral_hypothesis1(data,s1))#-log_likelihood_neutral_hypothesis1(data,s1))



def model101(x,key,data):
    s=x[0]
    tau=x[1]
    return -(np.log(1./mean_exp*np.exp(-1./mean_exp*s)*mut_rate*delta_s)+\
    log_likelihood_adaptive_hypothesis1(key,data,s,0,tau))

     


def model111(x,key,data):
    s=x[0]
    s1=x[1]
    tau=x[2]
    
    return -(np.log(1./mean_exp*np.exp(-1./mean_exp*(1*s))*1./mean_exp*np.exp(-1./mean_exp*(s1))*mut_rate*delta_s**2)+log_likelihood_adaptive_hypothesis1(key,data,s,s1,tau))#-log_likelihood_neutral_hypothesis1(data,s1))

# %%
#Estimation of the second derivative of the -loglike function around best estimator
# for calculating confidence intervals of those estimators
#Note : this is not a great way to calulate the Hessian...So if you have a better
# easier and consistent way go for it.

#I followed Blundell here (just added the abs value)

def hessian(x,dx):
    hessian=np.zeros((len(x),len(x)),dtype='f')
    for i in range(len(hessian)):
        for j in range(len(hessian)):
            hessian[i][j]=((x[i][2]-x[j][1])-(x[i][1]-x[j][0]))/(dx[i]*dx[j])
    w,v=np.linalg.eig(hessian)
    res=np.zeros(hessian.shape,dtype='f')
    for i in range(len(w)):
        res[i,i]=max([1./np.sqrt(w[z])*abs(np.dot(v[z],np.array([0 if p!=i else 1 for p in range(len(w))]).T))
                     for z in range(len(w))])
    print(res)
    return res

#I have really tried my best to inverse the Hessian rather than doing this weird diagonalization/
#back projection.
#The problem is if I don't do that and inverse the Hessian (which is what you should do)
# You get negative value, which are problematic for the square root following part.
#Those negative values are already there in the Hessian but only on non diagonal terms
# Which means that for s s1 and tau direction we are at a maximum but in the coupled directions,
# we are not : saddle point?

#I tried to follow that : https://se.mathworks.com/help/finance/ecmnhess.html
#without too much success

# %% [markdown]
# # Maximum likelihood

# %% [markdown]
# Performs ML for 3 different models: output is a text file where a line starting with > gives the different estimators for the different models and the log likelihood associated.
# Everything is separated by '\t'.
# So on the same line starting with > it goes like:
# - BC
# - estimators for one parameter model (0,s1,0) and the log likelihood
# - then estimators for the two parameters model (s,0,tau) and the log likelihood
# - finally estimators for the three parameters model (s,s1,tau) and the log likelihood.
#
# => so it is one string and 12 numbers per line starting with >
#
# Then you change line.
#
# On this new line starting with @ you will find the standard deviation on those estimators:
# - BC
# - 0,std s1,0
# - std s,0,std tau
# - std s,std s1,std tau
#
# => so it is one string and 9 numbers per line starting with @
#
# Also, the fitness of the rising mutant is always relative to the ancestral mutant: to have the fitness of the second mutant relative to the neutral lineage, you should add the rising mutant fitness to its ancestral fitness.

# %%
import multiprocessing

from multiprocessing import Process


adress_res="/Result_fit/result_fit.txt"

fitness_estimate010={}
fitness_estimate010_err={}

rranges =(slice(-0.1,0.2,0.001),)#range of fitness for one parameter model

fitness_estimate101={}
fitness_estimate101_err={}
rrranges=[[0.01,0.2],[-100,80]]#range of fitness and establishment time for two parameters model

fitness_estimate111={}
fitness_estimate111_err={}
rrrranges=[[0.01,0.2],[-0.1,0.2],[-100,80]]#range of fitness s and s1 and establishment time for three parameters model



for s in vr111:
    print(s)
    w=open(adress_res,'a')#add adress where ML analysis should be saved
    argumentes=[[0],s,data_dict[s]]
    #here since the dimension of the likelihood space is one we can afford using brute force optimization (please work with the number of workers you can afford)
    [estimate,fval,grid,Jout]=scipy.optimize.brute(model010,rranges,(s,data_dict[s]),finish=None,full_output=True,workers=10)
    
    fitness_estimate010[s]=[[0,estimate,0],-fval]
    print('fitness010',fitness_estimate010[s])
    rranges_err=(slice(estimate-0.02,estimate+0.02,0.01),)#range for curvature estimation : +/- grid size
    [estimate,fval,grid,Jout]=scipy.optimize.brute(model010,rranges_err,(s,data_dict[s]),finish=None,full_output=True,workers=10)
    h=np.gradient(np.gradient(Jout,0.01),0.01)
    fitness_estimate010_err[s]=[0,1./(np.sqrt(it*h[2])),0]# error is approximated by the 1 over sqrt of the second
    #derivative along the parameter of interest
    print('SD 1 param model',fitness_estimate010_err[s])
    
    ###############################################################
    #model101
    
    argumentes=[[fitness_estimate010[s][0][1],1],s,data_dict[s]]
    
    pro_list=[]
    manager = multiprocessing.Manager()
    mouff = manager.dict()
    for i in range(10):#(please work with the number of workers you can afford)
        p = Process(target=Nelder_Mead3_list, args=(i,mouff,model101,argumentes,1,0.5,2,0.5,rrranges,10**-6,100))
        pro_list.append(p)


    for p in pro_list:
        p.start()

    for p in pro_list:
        p.join()
    
    
    
    [estimate,fval]=sorted(mouff.values(),key=itemgetter(1))[0]
    fitness_estimate101[s]=[[estimate[0],0,estimate[1]],-fval]
    print('fitness101',fitness_estimate101[s])
    
    Jout=[[model101([estimate[0]+i*0.01,estimate[1]],s,data_dict[s]) for i in range(-1,2,1)]\
          ,[model101([estimate[0],estimate[1]+i],s,data_dict[s]) for i in range(-1,2,1)]]
    
    fitness_estimate101_err[s]=['nan',0,'nan']
    

        
    h=hessian(np.array(Jout),[0.01,1])
    print('hessian 2',h)
        
        
        
    
    try:
        fitness_estimate101_err[s][0]=h[0][0]
    except:
        None
    try:
        fitness_estimate101_err[s][2]=h[1][1]
    except:
        None
    print('SD 2 param model',fitness_estimate101_err[s])
    

    ##################################################################
    #model111
    
    argumentes=[[0.01,fitness_estimate010[s][0][1],1],s,data_dict[s]]
    
    
    pro_list=[]
    manager = multiprocessing.Manager()
    mouff = manager.dict()
    for i in range(10):#(please work with the number of workers you can afford)
        p = Process(target=Nelder_Mead3_list, args=(i,mouff,model111,argumentes,1,0.5,2,0.5,rrrranges,10**-6,100))
        pro_list.append(p)


    for p in pro_list:
        p.start()

    for p in pro_list:
        p.join()
    
       
    [estimate,fval]=sorted(mouff.values(),key=itemgetter(1))[0]
    fitness_estimate111[s]=[estimate,-fval]
    print('fitness111',fitness_estimate111[s])
    
    
    
    fitness_estimate111_err[s]=['nan','nan','nan']
    
    
    Jout=[[model111([estimate[0]+i*0.01,estimate[1],estimate[2]],s,data_dict[s]) for i in range(-1,2,1)]\
              ,[model111([estimate[0],estimate[1]+i*0.01,estimate[2]],s,data_dict[s]) for i in range(-1,2,1)]\
          ,[model111([estimate[0],estimate[1],estimate[2]+i],s,data_dict[s]) for i in range(-1,2,1)]]
    h=hessian(np.array(Jout),[0.01,0.01,1])#[:,:,1,2]
    for y in range(3):
        try:
            fitness_estimate111_err[s][y]=h[y][y]
        except:
            None    
    print('SD 3 param model',fitness_estimate111_err[s])    
    w.write('>'+str(s)+'\t'+str(fitness_estimate010[s][0][0])+'\t'+str(fitness_estimate010[s][0][1])+'\t'+str(fitness_estimate010[s][0][2])+'\t'+str(fitness_estimate010[s][1])\
           +'\t'+str(fitness_estimate101[s][0][0])+'\t'+str(fitness_estimate101[s][0][1])+'\t'+str(fitness_estimate101[s][0][2])+'\t'+str(fitness_estimate101[s][1])\
           +'\t'+str(fitness_estimate111[s][0][0])+'\t'+str(fitness_estimate111[s][0][1])+'\t'+str(fitness_estimate111[s][0][2])+'\t'+str(fitness_estimate111[s][1])+'\n')
    
    w.write('@'+str(s)+'\t'+str(fitness_estimate010_err[s][0])+'\t'+str(fitness_estimate010_err[s][1])+'\t'+str(fitness_estimate010_err[s][2])\
           +'\t'+str(fitness_estimate101_err[s][0])+'\t'+str(fitness_estimate101_err[s][1])+'\t'+str(fitness_estimate101_err[s][2])\
           +'\t'+str(fitness_estimate111_err[s][0])+'\t'+str(fitness_estimate111_err[s][1])+'\t'+str(fitness_estimate111_err[s][2])+'\n')
    w.close()
    print()
# Out:
# 273516
# fitness010 [[0, 0.11800000000000019, 0], -16538.571036779846]
# SD 1 param model [0, 2.0040797395354407e-06, 0]
# fitness101 [[0.1266411794869771, 0, -35.07437046640089], -2412.5749233284655]
# [[4.0215136e-06 0.0000000e+00]
#  [0.0000000e+00 3.0988488e-08]]
# hessian 2 [[4.0215136e-06 0.0000000e+00]
#  [0.0000000e+00 3.0988488e-08]]
# SD 2 param model [4.0215136e-06, 0, 3.0988488e-08]
# <ipython-input-178-0fababbf8d68>:16: RuntimeWarning: invalid value encountered in sqrt
#   res[i,i]=max([1./np.sqrt(w[z])*abs(np.dot(v[z],np.array([0 if p!=i else 1 for p in range(len(w))]).T))
# fitness111 [[0.08087275822499737, 0.11701821113478292, 24.537273695049443], -3994.2080740384963]
# [[2.0777229e-06 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 6.2313734e-06 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 7.2147657e-08]]
# SD 3 param model [2.077723e-06, 6.2313734e-06, 7.214766e-08]
#
# 221519
# fitness010 [[0, 0.11200000000000018, 0], -4160.423876996555]
# SD 1 param model [0, 2.4077546812756168e-06, 0]
# fitness101 [[0.1180893341972752, 0, -41.961629649780484], -4003.529992537946]
# [[4.387369e-06 0.000000e+00]
#  [0.000000e+00 3.430022e-08]]
# hessian 2 [[4.387369e-06 0.000000e+00]
#  [0.000000e+00 3.430022e-08]]
# SD 2 param model [4.387369e-06, 0, 3.430022e-08]
# fitness111 [[0.11680286102354417, 0.11026432956802482, 33.99956096929211], -970.758693613594]
# [[ 0.1376891   0.          0.        ]
#
# 130523
# fitness010 [[0, 0.07800000000000015, 0], -7833.857382796525]
# SD 1 param model [0, 9.027819914961607e-06, 0]
# fitness101 [[0.11752430611734418, 0, -12.156619335134902], -166.97606922165033]
# [[3.4660137e-05 0.0000000e+00]
#  [0.0000000e+00 2.5094184e-07]]
# hessian 2 [[3.4660137e-05 0.0000000e+00]
#  [0.0000000e+00 2.5094184e-07]]
# SD 2 param model [3.4660137e-05, 0, 2.5094184e-07]
# fitness111 [[0.11791741320596669, -0.0036998877327843313, -15.999999901349216], -127.33884424931026]
# [[1.4580649e-05 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.6083888e-05 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 1.6252505e-06]]
# SD 3 param model [1.4580649e-05, 1.6083888e-05, 1.6252505e-06]
#
# 419234
# fitness010 [[0, 0.08700000000000016, 0], -5697.527388983342]
# SD 1 param model [0, 9.47208204301095e-06, 0]
# fitness101 [[0.12018130402946334, 0, -9.495457340065233], -111.13882119605276]
# [[3.786811e-05 0.000000e+00]
#  [0.000000e+00 2.784197e-07]]
# hessian 2 [[3.786811e-05 0.000000e+00]
#  [0.000000e+00 2.784197e-07]]
# SD 2 param model [3.786811e-05, 0, 2.784197e-07]
# fitness111 [[0.11540909653075995, 0.006765103833963534, -7.9970165605583095], -99.56835519475601]
# [[0.00454972 0.         0.        ]
#  [0.         0.13924307 0.        ]
#  [0.         0.         2.2309346 ]]
# SD 3 param model [0.00454972, 0.13924307, 2.2309346]
#
# 214171
# fitness010 [[0, 0.08300000000000016, 0], -4759.031079038682]
# SD 1 param model [0, 9.522550595632358e-06, 0]
# fitness101 [[0.11355955497619294, 0, -14.511459530138326], -100.47046719740013]
# [[3.6533074e-05 0.0000000e+00]
#  [0.0000000e+00 2.6138630e-07]]
# hessian 2 [[3.6533074e-05 0.0000000e+00]
#  [0.0000000e+00 2.6138630e-07]]
# SD 2 param model [3.6533074e-05, 0, 2.613863e-07]
# fitness111 [[0.14884370458731944, -0.03585066547627132, -17.93256200352682], -110.23322467635128]
# [[1.5423257e-05 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.6586346e-05 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 2.2648753e-06]]
# SD 3 param model [1.5423257e-05, 1.6586346e-05, 2.2648753e-06]
#
# 42190
# fitness010 [[0, 0.07800000000000015, 0], -6034.565907927205]
# SD 1 param model [0, 9.842576714551962e-06, 0]
# fitness101 [[0.10420574848986075, 0, -22.71033328562246], -380.6910403600314]
# [[3.4213888e-05 0.0000000e+00]
#  [0.0000000e+00 2.5433232e-07]]
# hessian 2 [[3.4213888e-05 0.0000000e+00]
#  [0.0000000e+00 2.5433232e-07]]
# SD 2 param model [3.421389e-05, 0, 2.5433232e-07]
# fitness111 [[0.11578612115301516, -0.005602086121456805, -17.999864135414683], -135.2253303894597]
# [[1.5640395e-05 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.7264483e-05 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 1.7835013e-06]]
# SD 3 param model [1.5640395e-05, 1.7264483e-05, 1.7835013e-06]
#
# 11888
# fitness010 [[0, 0.08900000000000016, 0], -5194.765023225148]
# SD 1 param model [0, 1.0289384697563717e-05, 0]
# fitness101 [[0.13158968529660584, 0, 0.3166547801343109], -186.6954791883361]
# [[4.5503424e-05 0.0000000e+00]
#  [0.0000000e+00 3.1066739e-07]]
# hessian 2 [[4.5503424e-05 0.0000000e+00]
#  [0.0000000e+00 3.1066739e-07]]
# SD 2 param model [4.5503424e-05, 0, 3.106674e-07]
# fitness111 [[0.10784255102788172, 0.01885545446374883, -2.4926674575467347], -94.89924453832727]
# [[1.9147155e-05 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2
#
# 11668
# fitness010 [[0, 0.04000000000000012, 0], -1184.8997521021267]
# SD 1 param model [0, 5.9360298627768206e-05, 0]
# fitness101 [[0.12686230866870707, 0, 22.906564464686987], -77.10341160447578]
# [[3.2258261e-04 0.0000000e+00]
#  [0.0000000e+00 2.1946375e-06]]
# hessian 2 [[3.2258261e-04 0.0000000e+00]
#  [0.0000000e+00 2.1946375e-06]]
# SD 2 param model [0.0003225826, 0, 2.1946375e-06]
# fitness111 [[0.123346894811292, 0.008857032159602428, 25.73441801066567], -76.77611631934195]
# [[1.3614916e-04 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.6366677e-04 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 7.2955245e-06]]
# SD 3 param model [0.00013614916, 0.00016366677, 7.2955245e-06]
#
# 323329
# fitness010 [[0, 0.04100000000000012, 0], -1202.5376744502498]
# SD 1 param model [0, 5.771996753976344e-05, 0]
# fitness101 [[0.1165263066889713, 0, 16.616726880562226], -70.03809875221891]
# [[2.8175782e-04 0.0000000e+00]
#  [0.0000000e+00 1.9064536e-06]]
# hessian 2 [[2.8175782e-04 0.0000000e+00]
#  [0.0000000e+00 1.9064536e-06]]
# SD 2 param model [0.00028175782, 0, 1.9064536e-06]
# fitness111 [[0.1131884395439913, 0.0014232122819884158, 15.698009292099027], -72.48961195250627]
# [[ 0.06790474  0.          0.        ]
#  [ 0.          1.2530183   0.        ]
#  [ 0.          0.         28.370916  ]]
# SD 3 param model [0.06790474, 1.2530183, 28.370916]
#
# 485632
# fitness010 [[0, 0.03400000000000011, 0], -1237.2817639334041]
# SD 1 param model [0, 5.983020762423975e-05, 0]
# fitness101 [[0.11599189533316899, 0, 16.9874724476696], -70.54986881421421]
# [[2.8944504e-04 0.0000000e+00]
#  [0.0000000e+00 1.9755282e-06]]
# hessian 2 [[2.8944504e-04 0.0000000e+00]
#  [0.0000000e+00 1.9755282e-06]]
# SD 2 param model [0.00028944504, 0, 1.9755282e-06]
# fitness111 [[0.11581654686434492, 0.003310201931695321, 18.40817796917798], -73.8307406160007]
# [[  0.30994722   0.           0.        ]
#  [  0.           4.8724136    0.        ]
#  [  0.           0.         126.4337    ]]
# SD 3 param model [0.30994722, 4.8724136, 126.4337]
#
# 246739
# fitness010 [[0, 0.04400000000000012, 0], -764.0317780264758]
# SD 1 param model [0, 4.8766362493934975e-05, 0]
# fitness101 [[0.09445515139072529, 0, 0.7754041775043525], -70.70036822398464]
# [[2.1385774e-04 0.0000000e+00]
#  [0.0000000e+00 1.5312238e-06]]
# hessian 2 [[2.1385774e-04 0.0000000e+00]
#  [0.0000000e+00 1.5312238e-06]]
# SD 2 param model [0.00021385774, 0, 1.5312238e-06]
# fitness111 [[0.09062957588871337, 0.003910683757265477, 1.869248489135463], -73.032130276704]
# [[ 0.11394779  0.          0.        ]
#  [ 0.          1.7669911   0.        ]
#  [ 0.          0.         47.42545   ]]
# SD 3 param model [0.11394779, 1.7669911, 47.42545]

# %%
#calculating the portion of lineage mean fitness due to rising mutant
#this is how we will choose which model we want
#even if the 3 parameter model seems to fit the best, if at the end of the experiment
#the rising mutant is not contributing "significantly" to the lineage mean fitness
#then you are probably not really interested by this model
def adaptive_hypothesis_probability_mean(key,smoothie,x,s,s1,tau,Rt):
    
    
    found=False
    
    ending=int(sum([generation[i] for i in range(x)]))
    if tau<=0:
        found=True
        tau_int=int(tau)
        za=0
    
    
    if tau>0 and tau<ending:
        found=True
        tau_int=int(tau)
        za=int(tau/generation[0])
    zumo=int(generation[x])
    
    if found==True:
        
        s_anc=0
        s_mut=s
        cc=c
        if tau_int>=0:
            N=data_dict[key][za]/tot_pop[za]*N_e*np.exp(sum([s1-smoothie[i] for i in range(za*generation[0],tau_int)]))
        else:
            N=data_dict[key][za]/tot_pop[za]*N_e
    
        delta=1
        x_f=[cc/(s_mut-s_anc)*1./N]
        s_bar=[x_f[0]*(s_mut-s_anc)+s_anc]
        
        for i in range (1,ending+zumo-tau_int):
            x_f.append(x_f[i-1]*np.exp((s_mut-s_bar[i-1])*delta))
            s_bar.append(x_f[i]*(s_mut-s_anc)+s_anc)  
        T_s=sum([s for i in range(ending-tau_int,ending+zumo-tau_int)])
        T_s0=sum([s1-smoothie[i] for i in range(ending,ending+zumo)])
        
        if tau_int>=0:
            T_s_0=sum([s_bar[i]+s1-smoothie[i+tau_int] for i in range(ending-tau_int)])
            
        else:
            T_s_0=sum([s_bar[i-tau_int]+s1-smoothie[i] for i in range(ending)]+[s_bar[i]+s1-smoothie[0] for i in range(0,-tau_int)])
            
        New_tot=N*Rt*np.exp(T_s_0)/(N_e)
        x_f[ending-tau_int]*=New_tot
        mean_r_tT=x_f[ending-tau_int]*np.exp(T_s)*s/\
                       ((New_tot-x_f[ending-tau_int])*np.exp(T_s0)+x_f[ending-tau_int]*np.exp(T_s))
       
        result=mean_r_tT
        
        
            
    else:
        result=0
    
    return result

# %% [markdown]
# # Choosing model

# %%
#choosing model according to number of parameters and rising mutant contribution to lineage mean fitness
mean_lineage_fitness_thre=0.01# here the rising mutant should at least contribute to 1% of the final
# lineage mean fitness
from scipy import stats
fitness_estimate={}
fitness_err={}
bi={1:fitness_estimate010,2:fitness_estimate101,3:fitness_estimate111,0:{s:[[0,0,0],0] for s in fitness_estimate101.keys()}}
bi_err={1:fitness_estimate010_err,2:fitness_estimate101_err,3:fitness_estimate111_err,0:{s:[0,0,0] for s in fitness_estimate101.keys()}}

for s in fitness_estimate101.keys():
    sorted_loglike=sorted([[fitness_estimate010[s][1],1],[fitness_estimate101[s][1],2],[fitness_estimate111[s][1],3],[log_likelihood_neutral_hypothesis1(data_dict[s],0),0]],reverse=True,key=itemgetter(0))
    

    best_model=sorted_loglike[0]
    print('Model ordered by Loglikelihood',sorted_loglike)
    for i in range(1,4):
        
        if best_model[1]-sorted_loglike[i][1]>0:# just making sure that we are prioritizing lower number of paramters
            
            mean_pop_frac_explained=1
            
            if best_model[1]==3 or best_model[1]==2:
                mean_pop_frac_explained=adaptive_hypothesis_probability_mean(s,smooth_fitness,len(data_dict[s])-2\
                                         ,bi[best_model[1]][s][0][0],bi[best_model[1]][s][0][1],\
                                         bi[best_model[1]][s][0][2],tot_pop[-2])
                
                
                
            if mean_pop_frac_explained<mean_lineage_fitness_thre :
                
                best_model=sorted_loglike[i]
    print(s)
    
    fitness_estimate[s]=bi[best_model[1]][s]
    fitness_err[s]=bi_err[best_model[1]][s]
    print('fitness_estimate',fitness_estimate[s])
    print('fitness_err',fitness_err[s])
    print()
    
# Of course I tried AIC and BIC, but it was not conclusive. I was still overfitting
# a lot. Plus it seems that at least for BIC (which is based on a saddle point estimation
# of the bayseian version of the log likelihood), the loglikelihood function should behave 
# nicely (Hessian postive definite at the estimator point, which is not the case here)
# Out:
# Model ordered by Loglikelihood [[-2412.5749233284655, 2], [-3994.2080740384963, 3], [-16538.571036779846, 1], [-7431798.475805174, 0]]
# 273516
# fitness_estimate [[0.1266411794869771, 0, -35.07437046640089], -2412.5749233284655]
# fitness_err [4.0215136e-06, 0, 3.0988488e-08]
#
# Model ordered by Loglikelihood [[-970.758693613594, 3], [-4003.529992537946, 2], [-4160.423876996555, 1], [-5614624.5000543995, 0]]
# 221519
# fitness_estimate [[0.11680286102354417, 0.11026432956802482, 33.99956096929211], -970.758693613594]
# fitness_err [0.1376891, 0.42857984, 48.033825]
#
# Model ordered by Loglikelihood [[-450.35354686789725, 3], [-598.8591345928133, 2], [-3456.445021905966, 1], [-2672094.8355814135, 0]]
# 469936
# fitness_estimate [[0.1030491305532354, 0.11527043690769748, 34.99999746617267], -450.35354686789725]
# fitness_err [3.9406777e-06, 1.1802401e-05, 1.3512125e-07]
#
# Model ordered by Loglikelihood [[-758.0812698883149, 3], [-1442.5581792741762, 2], [-4548.448645341948, 1], [-2635074.2570529813, 0]]
# 245166
# fitness_estimate [[0.1716140928337698, 0.10863172373178667, 47.33900198656822], -758.0812698883149]
# fitness_err [0.39359814, 1.1458477, 129.55774]
#
# Model ordered by Loglikelihood [[-409.64102120317824, 2], [-438.4023018038576, 3], [-2421.390008733448, 1], [-1783145.8026411158, 0]]
# 163660
# fitness_estimate [[0.1217003301727122, 0, -28.875602040936947], -409.64102120317824]
# fitness_err [8.899402e-06, 0, 6.725162e-08]
#
# Model ordered by Loglikelihood [[-288.2831538305412, 2], [-421.4840432067862, 3], [-3537.0450182892923, 1], [-1401197.9337866262, 0]]
# 57993
# fitness_estimate [[0.12411201633960936, 0, -24.352381867583773], -288.2831538305412]
# fitness_err [1.0417727e-05, 0, 7.828367e-08]
#
# Model ordered by Loglikelihood [[-202.51422842441136, 3], [-320.452803479181, 2], [-868.1366360750196, 1], [-907085.2042195371, 0]]
# 247683
# fitness_estimate [[0.11661463045101172, 0, -27.370494702496913], -320.452803479181]
# fitness_err [1.2625295e-05, 0, 9.584043e-08]
#
# Model ordered by Loglikelihood [[-164.54375805111195, 3], [-385.13399418212026, 2], [-1130.6159930294027, 1], [-912321.1113406051, 0]]
# 178370
# fitness_estimate [[0.05982587741394753, 0.10416428036494683, 22.000004669335674], -164.54375805111195]
# fitness_err [0.43590364, 1.4963099, 168.23732]
#
# Model ordered by Loglikelihood [[-453.7627275197535, 2], [-498.85476737874967, 3], [-780.3308478633013, 1], [-812582.6884262369, 0]]
# 358580
# fitness_estimate [[0.110362735335664, 0, -32.758720294864496], -453.7627275197535]
# fitness_err [1.2756677e-05, 0, 9.753374e-08]
#
# Model ordered by Loglikelihood [[-157.3891609403985, 3], [-756.4578424593712, 1], [-765.9137020204685, 2], [-848003.4247688437, 0]]
# 488577
# fitness_estimate [[0.06155021095081022, 0.09624813892102832, 19.593191624340953], -157.3891609403985]
# fitness_err [5.246062e-06, 1.6244761e-05, 1.9040768e-07]
#
# Model ordered by Loglikelihood [[-203.12408515104264, 3], [-1132.8715215468217, 2], [-2015.9819796254405, 1], [-748318.1777298097, 0]]
# 41705
# fitness_estimate [[0.079030214499978, 0.0951761994494696, 27.99999970084206], -203.12408515104264]
# fitness_err [6.3872244e-06, 1.9673673e-05, 2.273931e-07]
#
# Model ordered by Loglikelihood [[-174.36342344631046, 3], [-523.9797387978333, 2], [-2073.0703146238448, 1], [-648238.0478184532, 0]]
# 2757
# fitness_estimate [[0.04725716917083113, 0.09443619447486049, 13.8618053000387], -174.36342344631046]
# fitness_err [0.222562, 0.79814833, 88.86455]
#
# Model ordered by Loglikelihood [[-187.89299990869728, 3], [-601.6028335407726, 1], [-681.142814006398, 2], [-562952.1716283048, 0]]
# 488093
# fitness_estimate [[0.14557534428361263, 0.09561091504443704, 48.03518921722683], -187.89299990869728]
# fitness_err [0.61772406, 1.8233861, 204.56435]
#
# Model ordered by Loglikelihood [[-149.8696954856398, 3], [-474.67489991057994, 2], [-1316.185441772865, 1], [-524989.537586141, 0]]
# 314714
# fitness_estimate [[0.043144760874217467, 0.08830647375006598, 5.557219183427238], -149.8696954856398]
# fitness_err [0.07323566, 0.31380728, 31.900122]
#
# Model ordered by Loglikelihood [[-99.41986325628466, 3], [-1927.098861162073, 2], [-25584.58782925132, 1], [-290444.4870384535, 0]]
# 199423
# fitness_estimate [[0.10815939756821684, 0.06340837666334335, 18.931216049293628], -99.41986325628466]
# fitness_err [1.5398731e-05, 2.0217962e-05, 6.0652883e-07]
#
# Model ordered by Loglikelihood [[-150.36824546079964, 3], [-163.16604864100913, 2], [-10963.628153364481, 1], [-297939.9535802027, 0]]
# 410311
# fitness_estimate [[0.13716745288228888, -0.013594704579998711, -13.754192727032521], -150.36824546079964]
# fitness_err [1.1259473e-05, 1.2229511e-05, 1.4872421e-06]
#
# Model ordered by Loglikelihood [[-127.57199862697982, 3], [-166.6832987066066, 2], [-15846.482350738821, 1], [-279778.9442776188, 0]]
# 496659
# fitness_estimate [[0.11940741919742222, 0.006147692658876538, -10.999983843663468], -127.57199862697982]
# fitness_err [0.0071080504, 0.23507166, 3.5593333]
#
# Model ordered by Loglikelihood [[-102.34372288797302, 3], [-110.47978852624968, 2], [-9034.562506773751, 1], [-242847.5981493506, 0]]
# 489013
# fitness_estimate [[0.11734891371991522, 0.005274248423331367, -11.864465091579586], -102.34372288797302]
# fitness_err [0.0031243544, 0.10503831, 1.5935322]
#
# Model ordered by Loglikelihood [[-113.81582808487559, 3], [-121.2097331414037, 2], [-11237.696986059225, 1], [-219282.68334723738, 0]]
# 482550
# fitness_estimate [[0.11505834990661437, 0.011377038321408454, -7.340250123055569], -113.81582808487559]
# fitness_err [0.005268534, 0.1542489, 2.5086782]
#
# Model ordered by Loglikelihood [[-169.83099501359604, 2], [-226.94573745871645, 3], [-14080.41015638668, 1], [-206719.17686779422, 0]]
# 42606
# fitness_estimate [[0.12281909059546639, 0, -10.751389977514808], -169.83099501359604]
# fitness_err [3.1252566e-05, 0, 2.2531987e-07]
#
# Model ordered by Loglikelihood [[-118.31043301876569, 3], [-218.09859878939977, 2], [-468.5103187309151, 1], [-263641.10494946834, 0]]
# 365669
# fitness_estimate [[0.061610717391913664, 0.09132354833134396, 24.80716254322845], -118.31043301876569]
# fitness_err [1.1092339e-05, 3.2984142e-05, 3.8537073e-07]
#
# Model ordered by Loglikelihood [[-116.95861310959562, 3], [-539.6228240086009, 2], [-804.4489343085917, 1], [-273335.5376875245, 0]]
# 238837
# fitness_estimate [[0.05342411966187631, 0.08436808768329258, 17.525683316154044], -116.95861310959562]
# fitness_err [9.423917e-06, 2.8616148e-05, 3.3646427e-07]
#
# Model ordered by Loglikelihood [[-111.2604006000093, 2], [-136.45346995976672, 3], [-12341.966006052615, 1], [-192896.19716845, 0]]
# 287102
# fitness_estimate [[0.12618681795146952, 0, -7.999997685265841], -111.2604006000093]
# fitness_err [3.346453e-05, 0, 2.3989938e-07]
#
# Model ordered by Loglikelihood [[-132.01128699061786, 2], [-260.65966960851324, 3], [-9669.013031996787, 1], [-195935.52704878524, 0]]
# 307912
# fitness_estimate [[0.1234637603230066, 0, -9.941285916731257], -132.01128699061786]
# fitness_err [3.263692e-05, 0, 2.3468164e-07]
#
# Model ordered by Loglikelihood [[-107.29812048106282, 2], [-108.19144316797838, 3], [-7873.500547176909, 1], [-190385.44418413966, 0]]
# 265282
# fitness_estimate [[0.12449814604551807, 0, -8.649387691338196], -107.29812048106282]
# fitness_err [3.3482822e-05, 0, 2.42447e-07]
#
# Model ordered by Loglikelihood [[-124.73333334895196, 3], [-246.52136230034992, 2], [-583.1454524300466, 1], [-236675.85740388595, 0]]
# 461680
# fitness_estimate [[0.0982692955810917, 0, -33.784274274791045], -246.52136230034992]
# fitness_err [2.3826393e-05, 0, 1.7999005e-07]
#
# Model ordered by Loglikelihood [[-141.60198095743885, 2], [-154.44645971227874, 3], [-14621.6110179481, 1], [-176719.6705778756, 0]]
# 445802
# fitness_estimate [[0.12561224787595343, 0, -7.244731986380259], -141.60198095743885]
# fitness_err [3.420196e-05, 0, 2.5241118e-07]
#
# Model ordered by Loglikelihood [[-128.52265046935406, 3], [-139.14779633392692, 2], [-12561.80192790249, 1], [-176013.28142767277, 0]]
# 117267
# fitness_estimate [[0.12239258486106437, -0.0023115479647972687, -11.37246618038365], -128.52265046935406]
# fitness_err [0.012364636, 0.41901714, 6.174124]
#
# Model ordered by Loglikelihood [[-119.74403059773623, 3], [-120.14382866143491, 2], [-12171.675520529832, 1], [-168278.26448611938, 0]]
# 343185
# fitness_estimate [[0.13054312777258395, -0.003921592061524041, -6.565603595881152], -119.74403059773623]
# fitness_err [1.5759451e-05, 1.7308697e-05, 1.7533688e-06]
#
# Model ordered by Loglikelihood [[-116.59216508975544, 2], [-186.29654460758445, 3], [-9688.80381764126, 1], [-170997.52253516132, 0]]
# 283517
# fitness_estimate [[0.11452614167734657, 0, -15.99304886680979], -116.59216508975544]
# fitness_err [3.2398097e-05, 0, 2.3888353e-07]
#
# Model ordered by Loglikelihood [[-119.0981068989072, 2], [-143.18698629461142, 3], [-11077.754096027726, 1], [-159801.3093424569, 0]]
# 240354
# fitness_estimate [[0.1256407792189136, 0, -6.871143038963968], -119.0981068989072]
# fitness_err [3.694118e-05, 0, 2.6709213e-07]
#
# Model ordered by Loglikelihood [[-110.99272000846278, 2], [-113.89626315668862, 3], [-8669.723981678597, 1], [-152572.26900965502, 0]]
# 182216
# fitness_estimate [[0.1280221040892429, 0, -4.615400104373332], -110.99272000846278]
# fitness_err [3.860744e-05, 0, 2.8231932e-07]
#
# Model ordered by Loglikelihood [[-127.33884424931026, 3], [-166.97606922165033, 2], [-7833.857382796525, 1], [-161959.3504782014, 0]]
# 130523
# fitness_estimate [[0.11791741320596669, -0.0036998877327843313, -15.999999901349216], -127.33884424931026]
# fitness_err [1.4580649e-05, 1.6083888e-05, 1.6252505e-06]
#
# Model ordered by Loglikelihood [[-99.56835519475601, 3], [-111.13882119605276, 2], [-5697.527388983342, 1], [-144595.58587058968, 0]]
# 419234
# fitness_estimate [[0.11540909653075995, 0.006765103833963534, -7.9970165605583095], -99.56835519475601]
# fitness_err [0.00454972, 0.13924307, 2.2309346]
#
# Model ordered by Loglikelihood [[-100.47046719740013, 2], [-110.23322467635128, 3], [-4759.031079038682, 1], [-145040.2106509049, 0]]
# 214171
# fitness_estimate [[0.11355955497619294, 0, -14.511459530138326], -100.47046719740013]
# fitness_err [3.6533074e-05, 0, 2.613863e-07]
#
# Model ordered by Loglikelihood [[-135.2253303894597, 3], [-380.6910403600314, 2], [-6034.565907927205, 1], [-136908.0816200443, 0]]
# 42190
# fitness_estimate [[0.11578612115301516, -0.005602086121456805, -17.999864135414683], -135.2253303894597]
# fitness_err [1.5640395e-05, 1.7264483e-05, 1.7835013e-06]
#
# Model ordered by Loglikelihood [[-94.89924453832727, 3], [-186.6954791883361, 2], [-5194.765023225148, 1], [-127367.29555936132, 0]]
# 11888
# fitness_estimate [[0.10784255102788172, 0.01885545446374883, -2.4926674575467347], -94.89924453832727]
# fitness_err [1.9147155e-05, 2.1631213e-05, 1.7008147e-06]
#
# Model ordered by Loglikelihood [[-109.68006189985799, 3], [-134.17796939681247, 2], [-7846.861056673703, 1], [-125347.89164231948, 0]]
# 118569
# fitness_estimate [[0.10863270634466834, 0.016799531468422536, -3.4941542491293727], -109.68006189985799]
# fitness_err [1.8870935e-05, 2.1324879e-05, 1.6565825e-06]
#
# Model ordered by Loglikelihood [[-109.67962765000095, 2], [-158.84257003228163, 3], [-7679.5475460088355, 1], [-126028.48529562661, 0]]
# 286369
# fitness_estimate [[0.11877842068992582, 0, -9.524316297940906], -109.67962765000095]
# fitness_err [4.0503954e-05, 0, 2.9340328e-07]
#
# Model ordered by Loglikelihood [[-107.22867140979037, 2], [-120.15477111591528, 3], [-7393.022988315162, 1], [-112656.53952084937, 0]]
# 446138
# fitness_estimate [[0.1230359108289236, 0, -5.745062804602272], -107.22867140979037]
# fitness_err [4.478192e-05, 0, 3.215288e-07]
#
# Model ordered by Loglikelihood [[-108.5127097345491, 2], [-160.46489948471347, 3], [-8065.050463569701, 1], [-108627.1652325563, 0]]
# 449074
# fitness_estimate [[0.12400083931979962, 0, -4.806949618891082], -108.5127097345491]
# fitness_err [4.6362857e-05, 0, 3.2719953e-07]
#
# Model ordered by Loglikelihood [[-109.76641821855766, 3], [-341.7978363157993, 1], [-365.4222231446269, 2], [-149705.11133358866, 0]]
# 456421
# fitness_estimate [[0.08822737960910423, 0.07841438492336653, 31.19846019139056], -109.76641821855766]
# fitness_err [24.826475, 81.03628, 8924.746]
#
# Model ordered by Loglikelihood [[-125.22755075507129, 3], [-130.9294836811367, 2], [-10080.167449596678, 1], [-103371.33130092782, 0]]
# 48296
# fitness_estimate [[0.12219301126936175, 0.006898004884529651, 0.19801060485925176], -125.22755075507129]
# fitness_err [0.03802394, 1.0756952, 17.599205]
#
# Model ordered by Loglikelihood [[-109.96006701022262, 3], [-144.16276037566297, 2], [-6805.949145233932, 1], [-107154.78682734768, 0]]
# 254353
# fitness_estimate [[0.10374018068712135, 0.02085228915544502, -2.734950186454948], -109.96006701022262]
# fitness_err [0.023912909, 0.5851236, 11.248746]
#
# Model ordered by Loglikelihood [[-101.17156348522845, 2], [-110.24470554198778, 3], [-4397.336802250351, 1], [-109351.46590364288, 0]]
# 408156
# fitness_estimate [[0.11698958464590717, 0, -9.706679611152428], -101.17156348522845]
# fitness_err [4.398867e-05, 0, 3.1830632e-07]
#
# Model ordered by Loglikelihood [[-109.40195384335257, 2], [-110.60152605420897, 3], [-7773.727441717984, 1], [-102143.31022110948, 0]]
# 287225
# fitness_estimate [[0.12343589944953298, 0, -4.6617190840020495], -109.40195384335257]
# fitness_err [4.7414414e-05, 0, 3.3976312e-07]
#
# Model ordered by Loglikelihood [[-96.15443125613159, 2], [-104.65128677701844, 3], [-5783.311849027296, 1], [-101694.10564218195, 0]]
# 56141
# fitness_estimate [[0.12318394077177261, 0, -4.326377998449078], -96.15443125613159]
# fitness_err [4.793947e-05, 0, 3.4349804e-07]
#
# Model ordered by Loglikelihood [[-106.46534091609267, 2], [-125.06504977805767, 3], [-6163.17993899124, 1], [-102284.5674519935, 0]]
# 475754
# fitness_estimate [[0.12049734669283993, 0, -6.250894180702129], -106.46534091609267]
# fitness_err [4.6574638e-05, 0, 3.349059e-07]
#
# Model ordered by Loglikelihood [[-107.21184446292229, 2], [-129.57335454608332, 3], [-6960.354089851071, 1], [-98076.29422966404, 0]]
# 124956
# fitness_estimate [[0.11872566307696197, 0, -7.049261455438899], -107.21184446292229]
# fitness_err [4.6950496e-05, 0, 3.3679783e-07]
#
# Model ordered by Loglikelihood [[-86.59642639204037, 3], [-124.65962299403914, 2], [-8835.477902895722, 1], [-87873.17603121379, 0]]
# 482854
# fitness_estimate [[0.11265123250710245, 0.015174378608546705, 1.9760108282734872], -86.59642639204037]
# fitness_err [2.3302808e-05, 2.6416754e-05, 1.9422857e-06]
#
# Model ordered by Loglikelihood [[-111.87502863257778, 3], [-164.21256327681866, 2], [-6519.00282149376, 1], [-93195.80301781626, 0]]
# 382691
# fitness_estimate [[0.10022400869718698, 0.01745479810804067, -6.316993401619173], -111.87502863257778]
# fitness_err [2.0830987e-05, 2.387483e-05, 1.6478115e-06]
#
# Model ordered by Loglikelihood [[-94.85420777575027, 2], [-106.9793935915895, 3], [-3980.7634252679277, 1], [-97318.33729177556, 0]]
# 133732
# fitness_estimate [[0.11445844539860478, 0, -10.270264974726189], -94.85420777575027]
# fitness_err [4.6067285e-05, 0, 3.337942e-07]
#
# Model ordered by Loglikelihood [[-130.20135558670486, 3], [-185.81102362991854, 2], [-8441.384855521082, 1], [-84287.59086073456, 0]]
# 247264
# fitness_estimate [[0.13132012432890827, -0.00895969346231057, -4.652193243532672], -130.20135558670486]
# fitness_err [2.2454344e-05, 2.470875e-05, 2.4067972e-06]
#
# Model ordered by Loglikelihood [[-82.09007633211726, 2], [-93.1865985347821, 3], [-6425.243112441537, 1], [-83943.90694820779, 0]]
# 325907
# fitness_estimate [[0.12859890344537514, 0, 1.5740707656389672], -82.09007633211726]
# fitness_err [5.5707358e-05, 0, 3.9490484e-07]
#
# Model ordered by Loglikelihood [[-116.35427956134254, 3], [-164.5357752169474, 2], [-232.76984019822663, 1], [-112082.5441221374, 0]]
# 307538
# fitness_estimate [[0.06780961140343286, 0.0845852852870316, 31.538454005466356], -116.35427956134254]
# fitness_err [1.6091974e-05, 5.1250838e-05, 5.927986e-07]
#
# Model ordered by Loglikelihood [[-91.83672205716653, 3], [-112.43520519256239, 2], [-7475.861460133419, 1], [-80503.66545211016, 0]]
# 490918
# fitness_estimate [[0.11535808194390493, 0.011679007143726458, 1.9986982978547903], -91.83672205716653]
# fitness_err [2.4527195e-05, 2.7649145e-05, 2.148301e-06]
#
# Model ordered by Loglikelihood [[-129.01437562010287, 2], [-130.79674715600345, 3], [-6082.077303788937, 1], [-83435.08548076786, 0]]
# 255821
# fitness_estimate [[0.11165194343012298, 0, -11.523835205386902], -129.01437562010287]
# fitness_err [4.9309197e-05, 0, 3.464219e-07]
#
# Model ordered by Loglikelihood [[-84.25996880192653, 2], [-86.39123257546618, 3], [-5164.915876340935, 1], [-75871.95037547885, 0]]
# 407350
# fitness_estimate [[0.12730952364895307, 0, 1.6355016715555488], -84.25996880192653]
# fitness_err [5.876759e-05, 0, 4.1674303e-07]
#
# Model ordered by Loglikelihood [[-86.51144147700008, 3], [-86.79897540725767, 2], [-6314.76565606738, 1], [-74169.80906683177, 0]]
# 266410
# fitness_estimate [[0.12194051035694328, 0.0033498684680782357, 0.6868824277705308], -86.51144147700008]
# fitness_err [2.5413332e-05, 2.8335246e-05, 2.5195848e-06]
#
# Model ordered by Loglikelihood [[-103.82012013292862, 3], [-106.3630834586298, 2], [-3039.691736796094, 1], [-81672.0366081723, 0]]
# 414160
# fitness_estimate [[0.14952569424931184, -0.03416406835828467, -10.997740794918348], -103.82012013292862]
# fitness_err [0.01644163, 0.6881315, 8.268079]
#
# Model ordered by Loglikelihood [[-82.82304054200341, 3], [-86.39947149648337, 2], [-4980.507330780661, 1], [-74804.8323523178, 0]]
# 254840
# fitness_estimate [[0.11459844944499462, 0.009940280789613934, 0.843163801864204], -82.82304054200341]
# fitness_err [0.019156946, 0.5127824, 8.887829]
#
# Model ordered by Loglikelihood [[-97.67594187459173, 3], [-101.7454130067856, 2], [-4363.64183246454, 1], [-80423.45393262952, 0]]
# 12533
# fitness_estimate [[0.13247907778909854, -0.02049528599569715, -12.001985713404443], -97.67594187459173]
# fitness_err [0.031238498, 1.222678, 16.27374]
#
# Model ordered by Loglikelihood [[-82.81262165959163, 2], [-93.2885995367117, 3], [-5382.428659307302, 1], [-71780.5515548968, 0]]
# 260964
# fitness_estimate [[0.12676326084326633, 0, 1.1589469284890903], -82.81262165959163]
# fitness_err [6.0043265e-05, 0, 4.3145334e-07]
#
# Model ordered by Loglikelihood [[-123.08933436860988, 2], [-195.5555011715729, 3], [-6949.422543818816, 1], [-71614.54461128196, 0]]
# 151456
# fitness_estimate [[0.11677055464394152, 0, -6.700833250125575], -123.08933436860988]
# fitness_err [5.5125787e-05, 0, 3.9529644e-07]
#
# Model ordered by Loglikelihood [[-126.50034991943046, 2], [-204.4364853604589, 3], [-8515.05183826071, 1], [-67920.36708540202, 0]]
# 270331
# fitness_estimate [[0.12499399357451776, 0, 0.017547460748854604], -126.50034991943046]
# fitness_err [6.019216e-05, 0, 4.1616258e-07]
#
# Model ordered by Loglikelihood [[-126.32448094583003, 3], [-137.26152762641965, 2], [-5296.182727596776, 1], [-73785.09027976693, 0]]
# 105881
# fitness_estimate [[0.0997599355139436, 0.021754629211107913, -1.161479988398989], -126.32448094583003]
# fitness_err [0.079004884, 1.7780427, 36.801945]
#
# Model ordered by Loglikelihood [[-157.39951176965036, 2], [-162.51867060648823, 3], [-6714.5961290779205, 1], [-71699.59696895904, 0]]
# 200896
# fitness_estimate [[0.12245618641359213, 0, -2.870045219505311], -157.39951176965036]
# fitness_err [5.7449943e-05, 0, 4.1034215e-07]
#
# Model ordered by Loglikelihood [[-95.32491248076043, 2], [-99.62944030164275, 3], [-4297.237132080883, 1], [-73325.60395471758, 0]]
# 216340
# fitness_estimate [[0.11799447074110972, 0, -5.99342973323761], -95.32491248076043]
# fitness_err [5.605007e-05, 0, 3.995583e-07]
#
# Model ordered by Loglikelihood [[-86.02069539281082, 3], [-131.9549381426343, 2], [-7692.416153211137, 1], [-68351.07219741376, 0]]
# 121016
# fitness_estimate [[0.11007624586675765, 0.013459516263923294, 0.7628473807671374], -86.02069539281082]
# fitness_err [0.01239585, 0.30362478, 5.7569623]
#
# Model ordered by Loglikelihood [[-97.07504952350742, 2], [-108.11432030974069, 3], [-3879.4910364321545, 1], [-70341.77204135137, 0]]
# 297019
# fitness_estimate [[0.12160051166651613, 0, -2.5541681265504343], -97.07504952350742]
# fitness_err [5.978013e-05, 0, 4.1806678e-07]
#
# Model ordered by Loglikelihood [[-87.1416239535501, 2], [-187.19406126369591, 3], [-7994.201517737057, 1], [-63882.923650231685, 0]]
# 155903
# fitness_estimate [[0.12425221654186122, 0, 0.8537985599128862], -87.1416239535501]
# fitness_err [6.197522e-05, 0, 4.3434886e-07]
#
# Model ordered by Loglikelihood [[-94.04012903999468, 3], [-142.9988103550533, 2], [-7688.258032074462, 1], [-63917.257400022834, 0]]
# 376292
# fitness_estimate [[0.11480905043057174, 0.009789438668288054, 1.069155769173677], -94.04012903999468]
# fitness_err [2.7252623e-05, 3.0817457e-05, 2.3665436e-06]
#
# Model ordered by Loglikelihood [[-84.61042505457787, 3], [-92.41204927688301, 2], [-7530.748810144754, 1], [-64269.40178223274, 0]]
# 278102
# fitness_estimate [[0.14757229639103428, -0.01867161585928123, 2.3286943685793], -84.61042505457787]
# fitness_err [0.072907194, 2.406966, 32.8053]
#
# Model ordered by Loglikelihood [[-87.54873989640521, 2], [-199.2779486523168, 3], [-2457.9955394160893, 1], [-72298.41735322728, 0]]
# 406173
# fitness_estimate [[0.1136151972698933, 0, -8.18739216592115], -87.54873989640521]
# fitness_err [5.5072083e-05, 0, 3.9678133e-07]
#
# Model ordered by Loglikelihood [[-94.35523738208185, 2], [-126.42924720856456, 3], [-3656.7930795539637, 1], [-75844.6870143548, 0]]
# 211601
# fitness_estimate [[0.10062086970909379, 0, -20.88070902937998], -94.35523738208185]
# fitness_err [4.6575075e-05, 0, 3.435865e-07]
#
# Model ordered by Loglikelihood [[-104.5745681285992, 2], [-136.2457582989967, 3], [-3741.5546596184877, 1], [-72112.84552786626, 0]]
# 208543
# fitness_estimate [[0.10773089050696263, 0, -13.751295376191514], -104.5745681285992]
# fitness_err [5.1556533e-05, 0, 3.7436112e-07]
#
# Model ordered by Loglikelihood [[-84.18517202518152, 2], [-95.77105462527888, 3], [-8072.596209962347, 1], [-60566.44144762781, 0]]
# 6073
# fitness_estimate [[0.12833905773331516, 0, 3.315467835249791], -84.18517202518152]
# fitness_err [6.594459e-05, 0, 4.6512423e-07]
#
# Model ordered by Loglikelihood [[-118.84096640222278, 3], [-291.32076974577205, 2], [-407.932419862737, 1], [-90495.99423404211, 0]]
# 201009
# fitness_estimate [[0.06091704174875519, 0.07704223010701526, 26.89805533219978], -118.84096640222278]
# fitness_err [0.59774643, 1.9079884, 213.06168]
#
# Model ordered by Loglikelihood [[-90.28179607157372, 3], [-125.63079351540699, 2], [-6978.18965624562, 1], [-61054.17704499041, 0]]
# 263127
# fitness_estimate [[0.12094763294660896, 0.0025610510124822986, 2.189836024570798e-05], -90.28179607157372]
# fitness_err [2.7294655e-05, 3.053265e-05, 2.534524e-06]
#
# Model ordered by Loglikelihood [[-79.17405545715032, 2], [-84.8725371535465, 3], [-5285.693640245594, 1], [-60415.63390144423, 0]]
# 126858
# fitness_estimate [[0.12626427468163412, 0, 2.4965588487227723], -79.17405545715032]
# fitness_err [6.6344975e-05, 0, 4.6928932e-07]
#
# Model ordered by Loglikelihood [[-104.58424790561817, 3], [-119.596740267273, 2], [-5017.637255034856, 1], [-63876.811694512675, 0]]
# 136292
# fitness_estimate [[0.1150571163375155, 0.0003246329811474643, -6.572540593210535], -104.58424790561817]
# fitness_err [0.030634902, 0.9238434, 15.13064]
#
# Model ordered by Loglikelihood [[-82.1976414595358, 2], [-85.32669225353995, 3], [-7213.426756181453, 1], [-58007.35395976771, 0]]
# 399866
# fitness_estimate [[0.12772570699532604, 0, 3.27829321527169], -82.1976414595358]
# fitness_err [6.7591776e-05, 0, 4.775042e-07]
#
# Model ordered by Loglikelihood [[-95.83217679953152, 2], [-100.3272586730761, 3], [-5129.786241761423, 1], [-60358.48716625923, 0]]
# 177866
# fitness_estimate [[0.12626730560204585, 0, 2.720144284728778], -95.83217679953152]
# fitness_err [6.631092e-05, 0, 4.686978e-07]
#
# Model ordered by Loglikelihood [[-81.15503483350791, 2], [-82.2079136429297, 3], [-8077.8857691182375, 1], [-53589.8189861843, 0]]
# 394921
# fitness_estimate [[0.12543948485406567, 0, 2.1093738946503957], -81.15503483350791]
# fitness_err [6.875218e-05, 0, 4.865998e-07]
#
# Model ordered by Loglikelihood [[-85.99624522775107, 2], [-99.27903380646346, 3], [-5718.358859885112, 1], [-56181.4452251593, 0]]
# 338638
# fitness_estimate [[0.12274356196499975, 0, 0.008834009694007605], -85.99624522775107]
# fitness_err [6.564226e-05, 0, 4.7501496e-07]
#
# Model ordered by Loglikelihood [[-94.93526044672105, 3], [-124.36007613237253, 2], [-5804.360590451869, 1], [-54190.63798592799, 0]]
# 99308
# fitness_estimate [[0.1045579943818455, 0.022797799622194227, 5.002942182930803], -94.93526044672105]
# fitness_err [0.07533386, 1.6039882, 34.44117]
#
# Model ordered by Loglikelihood [[-102.83826464410022, 2], [-112.05162833973773, 3], [-5260.450642664883, 1], [-57159.3237614498, 0]]
# 489595
# fitness_estimate [[0.11822051611886747, 0, -3.2171231860855087], -102.83826464410022]
# fitness_err [6.415511e-05, 0, 4.5737875e-07]
#
# Model ordered by Loglikelihood [[-77.66115907692162, 2], [-89.3226042122328, 3], [-5702.505784724408, 1], [-54822.324185245016, 0]]
# 64687
# fitness_estimate [[0.12520502770383032, 0, 2.772125334347841], -77.66115907692162]
# fitness_err [6.934177e-05, 0, 4.9074674e-07]
#
# Model ordered by Loglikelihood [[-78.77632294989627, 3], [-94.42709942037688, 2], [-3689.647225560846, 1], [-57804.87514765487, 0]]
# 310897
# fitness_estimate [[0.10246922361141594, 0.019296451758858982, 1.3967622782879032], -78.77632294989627]
# fitness_err [2.9024955e-05, 3.3313332e-05, 2.262789e-06]
#
# Model ordered by Loglikelihood [[-88.6465378065709, 3], [-91.99119798339296, 2], [-5365.1348935275555, 1], [-55631.29128733151, 0]]
# 164123
# fitness_estimate [[0.11342893823965142, 0.009411193056680669, 1.5603301743795863], -88.6465378065709]
# fitness_err [2.9262772e-05, 3.3082786e-05, 2.4985306e-06]
#
# Model ordered by Loglikelihood [[-91.59572731994072, 2], [-94.93792738622284, 3], [-5278.680672463257, 1], [-54226.69233835179, 0]]
# 367206
# fitness_estimate [[0.12347646289261674, 0, 1.7162834841196384], -91.59572731994072]
# fitness_err [6.901809e-05, 0, 4.8965046e-07]
#
# Model ordered by Loglikelihood [[-129.3795130859783, 3], [-148.34860002699858, 1], [-610.0235459063463, 2], [-85407.06897988207, 0]]
# 27799
# fitness_estimate [[0.13243896485959816, 0.0713837769864076, 49.9991871069703], -129.3795130859783]
# fitness_err [8.3174715, 24.01956, 2684.2073]
#
# Model ordered by Loglikelihood [[-82.12780705449948, 3], [-98.61046593063533, 2], [-6752.652308506371, 1], [-51185.29372047718, 0]]
# 465603
# fitness_estimate [[0.15082784607360095, -0.026859641504253497, 0.08613003231143965], -82.12780705449948]
# fitness_err [3.0276142e-05, 3.2937143e-05, 3.7236475e-06]
#
# Model ordered by Loglikelihood [[-123.78953776323607, 2], [-137.13895256096882, 3], [-5792.40342521377, 1], [-53610.98568878713, 0]]
# 343823
# fitness_estimate [[0.11502988421542322, 0, -5.755010124602379], -123.78953776323607]
# fitness_err [6.39278e-05, 0, 4.5812328e-07]
#
# Model ordered by Loglikelihood [[-91.9106505388853, 3], [-95.85697175927004, 2], [-5983.582945105214, 1], [-52217.903062073274, 0]]
# 476733
# fitness_estimate [[0.11139124903832451, 0.012082919675335353, 2.3589651649321626], -91.9106505388853]
# fitness_err [3.0244084e-05, 3.4487442e-05, 2.4014205e-06]
#
# Model ordered by Loglikelihood [[-84.76836263637462, 3], [-98.19814789300435, 2], [-7007.960257641419, 1], [-49217.07571114134, 0]]
# 238668
# fitness_estimate [[0.11849939924390314, 0.003896533022560375, 1.3922015152769762], -84.76836263637462]
# fitness_err [3.0549545e-05, 3.4408065e-05, 2.6534833e-06]
#
# Model ordered by Loglikelihood [[-92.78744352519743, 3], [-95.64076673574336, 2], [-1892.099413039282, 1], [-56256.61213624866, 0]]
# 405076
# fitness_estimate [[0.130443596604027, -0.01576413898909946, -6.228088430302785], -92.78744352519743]
# fitness_err [0.0064304764, 0.20560504, 2.97896]
#
# Model ordered by Loglikelihood [[-99.17098346249013, 2], [-110.17917483197446, 3], [-4101.873101977652, 1], [-54401.73405012194, 0]]
# 71509
# fitness_estimate [[0.11346755890946969, 0, -6.225913449336565], -99.17098346249013]
# fitness_err [6.380335e-05, 0, 4.57539e-07]
#
# Model ordered by Loglikelihood [[-88.51627789799805, 2], [-111.44672659230011, 3], [-2433.6999264689193, 1], [-57399.42297767454, 0]]
# 443870
# fitness_estimate [[0.10861592002595392, 0, -10.924245008445105], -88.51627789799805]
# fitness_err [6.046573e-05, 0, 4.3301407e-07]
#
# Model ordered by Loglikelihood [[-79.84323616658233, 2], [-94.9859682907977, 3], [-5792.523051662132, 1], [-47587.57673743844, 0]]
# 243695
# fitness_estimate [[0.12374277533760572, 0, 2.0010446168933713], -79.84323616658233]
# fitness_err [7.358843e-05, 0, 5.25623e-07]
#
# Model ordered by Loglikelihood [[-94.84268984092927, 2], [-112.32825726293028, 3], [-2028.1523841862154, 1], [-57682.04131007116, 0]]
# 220329
# fitness_estimate [[0.10521045546299282, 0, -13.832061780844231], -94.84268984092927]
# fitness_err [5.796135e-05, 0, 4.2534327e-07]
#
# Model ordered by Loglikelihood [[-88.25282268819998, 2], [-121.91554104941872, 3], [-8391.455077457427, 1], [-44545.37230646669, 0]]
# 83954
# fitness_estimate [[0.1267250531924286, 0, 4.89815622552751], -88.25282268819998]
# fitness_err [7.629423e-05, 0, 5.381044e-07]
#
# Model ordered by Loglikelihood [[-106.55638299923619, 3], [-108.33521442102196, 2], [-3581.407590418274, 1], [-51713.20926635329, 0]]
# 263925
# fitness_estimate [[0.11388971204537536, -0.0020867117561168694, -7.546127096984234], -106.55638299923619]
# fitness_err [2.7817281e-05, 3.1083742e-05, 2.6934176e-06]
#
# Model ordered by Loglikelihood [[-82.443497231467, 3], [-91.82520178331177, 2], [-5976.66667780534, 1], [-45830.53577330062, 0]]
# 483038
# fitness_estimate [[0.1206350830509954, 0.0038363860816065243, 3.2046221177135124], -82.443497231467]
# fitness_err [0.058694653, 1.5515074, 26.830162]
#
# Model ordered by Loglikelihood [[-109.24436858542057, 3], [-118.27340153163699, 2], [-5401.898237917152, 1], [-48905.97968420833, 0]]
# 142130
# fitness_estimate [[0.11067604850288441, 0.009255193034293521, 0.9077796503624284], -109.24436858542057]
# fitness_err [0.012991824, 0.31290412, 5.900492]
#
# Model ordered by Loglikelihood [[-77.71400606024628, 3], [-84.26183646095463, 2], [-4323.6989973773925, 1], [-47836.294453231014, 0]]
# 305342
# fitness_estimate [[0.11449844099762488, 0.008043702163238457, 2.983201365363224], -77.71400606024628]
# fitness_err [3.2169548e-05, 3.6323116e-05, 2.7832698e-06]
#
# Model ordered by Loglikelihood [[-79.41855438906272, 2], [-93.12344225519627, 3], [-6676.062579354051, 1], [-44067.99479898623, 0]]
# 385102
# fitness_estimate [[0.12615110935529147, 0, 4.222584142999741], -79.41855438906272]
# fitness_err [7.7987424e-05, 0, 5.499054e-07]
#
# Model ordered by Loglikelihood [[-115.0300949262757, 2], [-146.75533703192272, 3], [-4211.6829530219975, 1], [-49439.79358678442, 0]]
# 113872
# fitness_estimate [[0.1087652650598093, 0, -9.204449436782474], -115.0300949262757]
# fitness_err [6.422379e-05, 0, 4.64647e-07]
#
# Model ordered by Loglikelihood [[-81.32786172485069, 2], [-96.89994471655783, 3], [-4716.175802577916, 1], [-44239.820841579065, 0]]
# 498849
# fitness_estimate [[0.12762306231625242, 0, 5.717069199098683], -81.32786172485069]
# fitness_err [7.907253e-05, 0, 5.75674e-07]
#
# Model ordered by Loglikelihood [[-88.89280272419437, 2], [-96.80295930951812, 3], [-3727.376232807118, 1], [-46521.610474633875, 0]]
# 408811
# fitness_estimate [[0.12015684894097073, 0, 0.37312196799486763], -88.89280272419437]
# fitness_err [7.330238e-05, 0, 5.2236936e-07]
#
# Model ordered by Loglikelihood [[-86.9990420051468, 3], [-90.60543511993278, 2], [-4474.280543698394, 1], [-43836.82699428911, 0]]
# 416598
# fitness_estimate [[0.10234255430517396, 0.020825853091203363, 4.000329035131758], -86.9990420051468]
# fitness_err [3.376101e-05, 3.9299746e-05, 2.3671646e-06]
#
# Model ordered by Loglikelihood [[-96.85735221152008, 3], [-98.15953927525116, 2], [-3396.8175795625707, 1], [-45606.20111378813, 0]]
# 487782
# fitness_estimate [[0.12595099597814752, -0.010701308622734398, -4.559779977708924], -96.85735221152008]
# fitness_err [3.0632855e-05, 3.3869634e-05, 3.1432996e-06]
#
# Model ordered by Loglikelihood [[-84.41647717148598, 3], [-100.56388205589515, 2], [-2588.8086884699933, 1], [-46296.73325797106, 0]]
# 17626
# fitness_estimate [[0.10514619207093948, 0.013166387046270519, 0.30532761320451596], -84.41647717148598]
# fitness_err [3.194497e-05, 3.6394835e-05, 2.6522684e-06]
#
# Model ordered by Loglikelihood [[-120.39713983369096, 3], [-171.80247622663066, 2], [-472.6288809928162, 1], [-61760.65445471948, 0]]
# 205268
# fitness_estimate [[0.07801304143121195, 0.06967334545911116, 28.85897911549997], -120.39713983369096]
# fitness_err [2.4224139e-05, 6.8512956e-05, 8.122569e-07]
#
# Model ordered by Loglikelihood [[-83.11223945606247, 2], [-88.42880319642907, 3], [-4528.216003250669, 1], [-42579.567689081596, 0]]
# 198628
# fitness_estimate [[0.12048571010138487, 0, 1.6844752536921908], -83.11223945606247]
# fitness_err [7.842616e-05, 0, 5.411544e-07]
#
# Model ordered by Loglikelihood [[-122.9167919983831, 3], [-358.22062363459185, 2], [-442.7941544958862, 1], [-62658.829067594066, 0]]
# 13357
# fitness_estimate [[0.05374560060032715, 0.03942547890540678, -17.718764829901517], -122.9167919983831]
# fitness_err [1.9594985e-05, 3.0970557e-05, 6.6700807e-07]
#
# Model ordered by Loglikelihood [[-91.15183187683583, 3], [-111.80547240268544, 2], [-4880.163620636758, 1], [-42018.63264485023, 0]]
# 54479
# fitness_estimate [[0.10634964948492451, 0.011378972380069928, 0.0352966566062598], -91.15183187683583]
# fitness_err [3.2990534e-05, 3.789772e-05, 2.5999243e-06]
#
# Model ordered by Loglikelihood [[-81.32950957888156, 3], [-102.5744007261357, 2], [-4342.338924888141, 1], [-42302.60034783998, 0]]
# 451210
# fitness_estimate [[0.1017248132757553, 0.018207101791838095, 2.918604171882076], -81.32950957888156]
# fitness_err [3.34232e-05, 3.8914433e-05, 2.3215182e-06]
#
# Model ordered by Loglikelihood [[-80.36308936301732, 3], [-83.13563649420956, 2], [-4409.414394522101, 1], [-40059.60667146634, 0]]
# 26056
# fitness_estimate [[0.120309302025385, 0.006712863772502351, 6.170848831486265], -80.36308936301732]
# fitness_err [0.019402908, 0.47110116, 8.435583]
#
# Model ordered by Loglikelihood [[-113.53984047357287, 3], [-119.07579752099288, 2], [-5344.596084580084, 1], [-41282.23686565331, 0]]
# 408836
# fitness_estimate [[0.12490800087709764, -0.005227921501326375, 0.9990927215808737], -113.53984047357287]
# fitness_err [0.023655867, 0.66445833, 10.706115]
#
# Model ordered by Loglikelihood [[-92.89878185476978, 3], [-116.4729970379062, 2], [-5004.853908190333, 1], [-41515.73799646828, 0]]
# 71182
# fitness_estimate [[0.12160515630130574, -0.0022880064949179846, 0.9999995225020359], -92.89878185476978]
# fitness_err [0.030516857, 0.8450423, 14.021385]
#
# Model ordered by Loglikelihood [[-84.55858656646527, 2], [-96.54346817809852, 3], [-5375.412648060986, 1], [-38443.06952860505, 0]]
# 118523
# fitness_estimate [[0.12910093601609324, 0, 7.560046443025811], -84.55858656646527]
# fitness_err [8.835291e-05, 0, 5.965273e-07]
#
# Model ordered by Loglikelihood [[-80.41708566485686, 3], [-80.73552285654281, 2], [-4875.933278024291, 1], [-39815.66162323944, 0]]
# 140481
# fitness_estimate [[0.11957248256939726, 0.005970063623124961, 5.448619746250503], -80.41708566485686]
# fitness_err [0.04674134, 1.1521393, 20.684397]
#
# Model ordered by Loglikelihood [[-86.25845280353417, 2], [-180.35142174149794, 3], [-5123.18654784725, 1], [-40225.902523350844, 0]]
# 155194
# fitness_estimate [[0.11896853239715938, 0, 0.015730091680789204], -86.25845280353417]
# fitness_err [7.7185294e-05, 0, 5.504737e-07]
#
# Model ordered by Loglikelihood [[-75.47085749236155, 2], [-109.58258875587538, 3], [-5006.20957940763, 1], [-39349.53224630757, 0]]
# 466487
# fitness_estimate [[0.12278860205085773, 0, 3.3687229531188194], -75.47085749236155]
# fitness_err [8.286706e-05, 0, 5.750314e-07]
#
# Model ordered by Loglikelihood [[-78.44376099535044, 3], [-89.29041807962888, 2], [-5061.334170287792, 1], [-39616.29642606154, 0]]
# 407798
# fitness_estimate [[0.12657092313720164, -0.00466926971879083, 2.589379353676943], -78.44376099535044]
# fitness_err [0.010597121, 0.29895508, 4.8323402]
#
# Model ordered by Loglikelihood [[-79.42108886487794, 3], [-94.10737448625207, 2], [-3914.391278281097, 1], [-41647.13181062173, 0]]
# 309808
# fitness_estimate [[0.10375630982987163, 0.014802520834682772, 1.163558007335746], -79.42108886487794]
# fitness_err [3.3604225e-05, 3.8685936e-05, 2.534744e-06]
#
# Model ordered by Loglikelihood [[-86.36517396079957, 3], [-90.63385677230069, 2], [-2469.1620121811648, 1], [-42792.56740385358, 0]]
# 479831
# fitness_estimate [[0.14001443915829234, -0.025878098490023836, -5.773644138795403], -86.36517396079957]
# fitness_err [3.2016735e-05, 3.4946137e-05, 3.8131152e-06]
#
# Model ordered by Loglikelihood [[-81.36779297522796, 3], [-96.60846232418864, 2], [-3178.3398182123665, 1], [-41343.268291004264, 0]]
# 298414
# fitness_estimate [[0.09314161233552207, 0.025134527330535762, 2.7860825669532563], -81.36779297522796]
# fitness_err [0.058046833, 1.1040295, 26.187965]
#
# Model ordered by Loglikelihood [[-89.87627313178034, 3], [-90.05279161244512, 2], [-4700.280214696686, 1], [-38605.97470566807, 0]]
# 115202
# fitness_estimate [[0.11716213720729943, 0.0037667418397245556, 2.000095735750759], -89.87627313178034]
# fitness_err [3.477599e-05, 3.9211e-05, 2.8887491e-06]
#
# Model ordered by Loglikelihood [[-78.34565891575373, 2], [-90.23179687219718, 3], [-5044.247568830882, 1], [-37354.65825296193, 0]]
# 330865
# fitness_estimate [[0.12709195268462226, 0, 6.919708209333719], -78.34565891575373]
# fitness_err [8.791537e-05, 0, 6.1453136e-07]
#
# Model ordered by Loglikelihood [[-88.13209021781009, 3], [-91.14502234069643, 2], [-1716.4387721410212, 1], [-43500.91962811514, 0]]
# 482945
# fitness_estimate [[0.08831580497726395, 0.027071636846823646, 0.15063503842213155], -88.13209021781009]
# fitness_err [0.09455956, 1.9433045, 44.722263]
#
# Model ordered by Loglikelihood [[-82.36904994028586, 3], [-101.13273910253984, 2], [-5608.649849475587, 1], [-36004.278277672165, 0]]
# 53799
# fitness_estimate [[0.11877784451084003, 0.007361224087269651, 6.169088790827089], -82.36904994028586]
# fitness_err [3.786216e-05, 4.303904e-05, 3.0096387e-06]
#
# Model ordered by Loglikelihood [[-80.4880763229963, 3], [-84.02842934142333, 2], [-3350.665734763371, 1], [-39316.14366376908, 0]]
# 84784
# fitness_estimate [[0.130256575777038, -0.008477099379583965, 2.0968389326585557], -80.4880763229963]
# fitness_err [3.5776044e-05, 3.963189e-05, 3.581939e-06]
#
# Model ordered by Loglikelihood [[-87.70168968337592, 3], [-88.50608387192473, 2], [-5001.74760389349, 1], [-37396.80134448782, 0]]
# 109855
# fitness_estimate [[0.10880650425042196, 0.013540840537063647, 4.8421349323281735], -87.70168968337592]
# fitness_err [3.6266738e-05, 4.196937e-05, 2.6160103e-06]
#
# Model ordered by Loglikelihood [[-83.8015494430583, 2], [-130.1785674803051, 3], [-5250.466857132226, 1], [-36323.019986612315, 0]]
# 412500
# fitness_estimate [[0.12367806175249119, 0, 4.138277798815825], -83.8015494430583]
# fitness_err [8.6142914e-05, 0, 6.0624393e-07]
#
# Model ordered by Loglikelihood [[-78.38863573469979, 2], [-79.73627623053724, 3], [-2600.735475571538, 1], [-39947.42514730204, 0]]
# 471998
# fitness_estimate [[0.1194361599228303, 0, 1.6096852553994192], -78.38863573469979]
# fitness_err [8.150357e-05, 0, 5.78997e-07]
#
# Model ordered by Loglikelihood [[-94.72618239570987, 3], [-104.43799183439882, 2], [-2415.316484786367, 1], [-42208.984201951585, 0]]
# 182281
# fitness_estimate [[0.08064357404170538, 0.035777853654831424, 2.6732967432775725], -94.72618239570987]
# fitness_err [3.3206084e-05, 4.159782e-05, 1.6694485e-06]
#
# Model ordered by Loglikelihood [[-80.75683416311705, 2], [-119.68423882517733, 3], [-4751.017903094105, 1], [-36965.18836440659, 0]]
# 409207
# fitness_estimate [[0.12222405757135074, 0, 3.6204138025725605], -80.75683416311705]
# fitness_err [8.442832e-05, 0, 6.0454454e-07]
#
# Model ordered by Loglikelihood [[-74.45512334905585, 2], [-78.96340816023873, 3], [-3270.045737233523, 1], [-36797.05272533238, 0]]
# 52596
# fitness_estimate [[0.12648324172067307, 0, 6.346884034330955], -74.45512334905585]
# fitness_err [8.990554e-05, 0, 6.302688e-07]
#
# Model ordered by Loglikelihood [[-79.43449971821536, 2], [-101.263833582181, 3], [-6053.430316806226, 1], [-33975.55348773397, 0]]
# 250241
# fitness_estimate [[0.12811023667150162, 0, 7.7712075660716735], -79.43449971821536]
# fitness_err [9.15315e-05, 0, 6.4189027e-07]
#
# Model ordered by Loglikelihood [[-117.82938971810623, 3], [-125.20986370029556, 2], [-2899.3291860015675, 1], [-39936.589074517025, 0]]
# 278637
# fitness_estimate [[0.10825693930914485, -0.002943476581676242, -10.999999110854215], -117.82938971810623]
# fitness_err [3.0500418e-05, 3.4244895e-05, 2.889869e-06]
#
# Model ordered by Loglikelihood [[-77.31830009191677, 3], [-83.13432127023003, 2], [-3899.2621344126524, 1], [-36157.89260919696, 0]]
# 22887
# fitness_estimate [[0.11021250234760979, 0.013136435230782619, 5.700434156323714], -77.31830009191677]
# fitness_err [0.020360053, 0.46080872, 9.106043]
#
# Model ordered by Loglikelihood [[-84.9068667294287, 3], [-91.26228189470503, 2], [-5811.310012052993, 1], [-32885.627271528334, 0]]
# 113279
# fitness_estimate [[0.11217608140926373, 0.01706048013228393, 9.031430598928797], -84.9068667294287]
# fitness_err [0.024689091, 0.50689346, 10.717093]
#
# Model ordered by Loglikelihood [[-92.61864902245202, 3], [-94.04920508260314, 2], [-3287.8264948544656, 1], [-38846.59894765409, 0]]
# 363831
# fitness_estimate [[0.10179031555395615, 0.01568686350573786, 1.3553094681931843], -92.61864902245202]
# fitness_err [3.486943e-05, 4.0265026e-05, 2.5919328e-06]
#
# Model ordered by Loglikelihood [[-84.71802102056117, 3], [-105.22932585624005, 2], [-3874.5274950676744, 1], [-37372.79861834887, 0]]
# 447585
# fitness_estimate [[0.10316894620060027, 0.012741692243376786, 0.11113276738082087], -84.71802102056117]
# fitness_err [0.03435975, 0.72444564, 15.057368]
#
# Model ordered by Loglikelihood [[-82.15552374551346, 3], [-91.61445823099824, 2], [-2382.2140028614067, 1], [-38973.32965758701, 0]]
# 301213
# fitness_estimate [[0.09319957088612586, 0.02303127182137517, 1.000000110520736], -82.15552374551346]
# fitness_err [3.5057237e-05, 4.104714e-05, 2.4384115e-06]
#
# Model ordered by Loglikelihood [[-74.74016317787424, 2], [-76.94193257778711, 3], [-5102.768874048694, 1], [-34418.096685427285, 0]]
# 431025
# fitness_estimate [[0.12628032516536852, 0, 6.550161925929167], -74.74016317787424]
# fitness_err [9.071289e-05, 0, 6.3879946e-07]
#
# Model ordered by Loglikelihood [[-83.73697470593585, 2], [-94.03916425529333, 3], [-4566.669124499302, 1], [-34517.98095020691, 0]]
# 74843
# fitness_estimate [[0.12136103375721727, 0, 3.4274744004894977], -83.73697470593585]
# fitness_err [8.766244e-05, 0, 6.179046e-07]
#
# Model ordered by Loglikelihood [[-79.82206799844994, 3], [-81.97934052270577, 2], [-4990.29049595569, 1], [-33927.04752869547, 0]]
# 200212
# fitness_estimate [[0.11584068107118248, 0.009182385283063917, 6.255485914702614], -79.82206799844994]
# fitness_err [3.9148348e-05, 4.4752163e-05, 3.0293015e-06]
#
# Model ordered by Loglikelihood [[-81.2260176057728, 2], [-92.28665028902128, 3], [-4334.479032100095, 1], [-34780.55215689846, 0]]
# 488180
# fitness_estimate [[0.1215985219445925, 0, 3.8501341820455854], -81.2260176057728]
# fitness_err [8.6434644e-05, 0, 6.27171e-07]
#
# Model ordered by Loglikelihood [[-87.38341222999004, 2], [-150.7726038978698, 3], [-4561.607232363382, 1], [-33962.85925254683, 0]]
# 230244
# fitness_estimate [[0.12273036097782083, 0, 4.558798947007011], -87.38341222999004]
# fitness_err [8.949278e-05, 0, 6.300323e-07]
#
# Model ordered by Loglikelihood [[-93.38805349504659, 2], [-114.83823649089645, 3], [-4453.316299497423, 1], [-34561.77227230827, 0]]
# 308304
# fitness_estimate [[0.11975414088853319, 0, 2.9869973808323547], -93.38805349504659]
# fitness_err [8.70281e-05, 0, 6.047438e-07]
#
# Model ordered by Loglikelihood [[-103.11349860245616, 3], [-121.76985988204694, 2], [-3143.9626477743004, 1], [-37197.05244478137, 0]]
# 239984
# fitness_estimate [[0.11184803427123838, 0.0065619879374404656, 1.9297078475006266], -103.11349860245616]
# fitness_err [0.012032275, 0.33978096, 6.023255]
#
# Model ordered by Loglikelihood [[-134.30164877510913, 3], [-137.31881534301635, 2], [-4303.919675722606, 1], [-35650.46809408907, 0]]
# 425127
# fitness_estimate [[0.10298597618645812, 0.006484732638983101, -5.461123522941612], -134.30164877510913]
# fitness_err [3.3581524e-05, 3.853323e-05, 2.7453355e-06]
#
# Model ordered by Loglikelihood [[-81.18229090779708, 2], [-85.66816851919442, 3], [-5055.695498824518, 1], [-32287.776721877817, 0]]
# 252849
# fitness_estimate [[0.12547134167100793, 0, 6.908723181554629], -81.18229090779708]
# fitness_err [9.375549e-05, 0, 6.582754e-07]
#
# Model ordered by Loglikelihood [[-78.21844256155731, 3], [-78.491440283371, 2], [-4884.537684003568, 1], [-32415.175061254424, 0]]
# 166823
# fitness_estimate [[0.118574103248832, 0.009320464033841413, 8.275287168241771], -78.21844256155731]
# fitness_err [4.1202195e-05, 4.6848894e-05, 3.2618684e-06]
#
# Model ordered by Loglikelihood [[-82.54312234944996, 2], [-84.7114747595315, 3], [-5691.394224873505, 1], [-31966.75908814322, 0]]
# 181219
# fitness_estimate [[0.12404679986239048, 0, 5.083918964243585], -82.54312234944996]
# fitness_err [9.1784e-05, 0, 6.4490945e-07]
#
# Model ordered by Loglikelihood [[-78.80904384440281, 2], [-80.30995049590123, 3], [-5172.430674172031, 1], [-31992.042800864892, 0]]
# 346464
# fitness_estimate [[0.12386011610414482, 0, 5.290131791662324], -78.80904384440281]
# fitness_err [9.236388e-05, 0, 6.532896e-07]
#
# Model ordered by Loglikelihood [[-87.27507987833656, 3], [-90.03352725015965, 2], [-4348.552543119689, 1], [-33898.66663589362, 0]]
# 385642
# fitness_estimate [[0.10568623856149975, 0.010112032361852888, 0.08075460039381088], -87.27507987833656]
# fitness_err [3.5450492e-05, 4.0790685e-05, 2.6705468e-06]
#
# Model ordered by Loglikelihood [[-88.12469345076545, 3], [-104.34266056843967, 2], [-4510.9739559976315, 1], [-33654.95375072006, 0]]
# 19066
# fitness_estimate [[0.11378147944602793, 0.002750007338359466, 0.17788874651923425], -88.12469345076545]
# fitness_err [0.0135743655, 0.34879288, 6.3281283]
#
# Model ordered by Loglikelihood [[-79.2036673925574, 2], [-80.40048984002138, 3], [-3874.7808050764424, 1], [-32464.18055469542, 0]]
# 179126
# fitness_estimate [[0.12352472837591272, 0, 5.276974662425245], -79.2036673925574]
# fitness_err [9.354319e-05, 0, 6.596501e-07]
#
# Model ordered by Loglikelihood [[-80.07741173323517, 2], [-135.18988250482371, 3], [-3799.7378812652373, 1], [-33174.39106200741, 0]]
# 403590
# fitness_estimate [[0.11768396154812247, 0, 1.2931518327398472], -80.07741173323517]
# fitness_err [8.7831075e-05, 0, 6.205042e-07]
#
# Model ordered by Loglikelihood [[-78.42162487486894, 3], [-91.97385982844585, 2], [-4220.677809845699, 1], [-31636.617394203397, 0]]
# 76795
# fitness_estimate [[0.11017268819207712, 0.014842758049421981, 7.495928218309287], -78.42162487486894]
# fitness_err [0.025078095, 0.5261701, 11.08188]
#
# Model ordered by Loglikelihood [[-80.89914327859931, 2], [-82.23377394884233, 3], [-5535.770497397663, 1], [-29993.379878339045, 0]]
# 236149
# fitness_estimate [[0.1233882200734214, 0, 5.431440920717735], -80.89914327859931]
# fitness_err [9.431387e-05, 0, 6.624782e-07]
#
# Model ordered by Loglikelihood [[-80.47075963452254, 2], [-101.8897645795898, 3], [-4206.265358732016, 1], [-31540.73560052599, 0]]
# 467596
# fitness_estimate [[0.12174319504526775, 0, 4.407186234400878], -80.47075963452254]
# fitness_err [9.3106486e-05, 0, 6.549974e-07]
#
# Model ordered by Loglikelihood [[-85.72301929191008, 2], [-99.14188635022163, 3], [-4530.028608874558, 1], [-32012.948450764125, 0]]
# 313008
# fitness_estimate [[0.11937188967230805, 0, 2.0696289113654163], -85.72301929191008]
# fitness_err [8.776909e-05, 0, 6.439451e-07]
#
# Model ordered by Loglikelihood [[-86.31055007239183, 3], [-93.15631847462481, 2], [-3311.5944286967065, 1], [-33442.609837327815, 0]]
# 35888
# fitness_estimate [[0.10355412550825185, 0.012627470324337076, 1.4133529235596973], -86.31055007239183]
# fitness_err [3.727257e-05, 4.2979045e-05, 2.7791907e-06]
#
# Model ordered by Loglikelihood [[-79.26144306945706, 2], [-95.07755840677494, 3], [-2695.425133263494, 1], [-33535.73517156258, 0]]
# 388751
# fitness_estimate [[0.11584413459460428, 0, 0.47407094804475847], -79.26144306945706]
# fitness_err [8.828989e-05, 0, 6.086517e-07]
#
# ...
# fitness_err [0.00024915236, 0, 1.7527402e-06]
#
# Model ordered by Loglikelihood [[-80.85129004852053, 3], [-81.73406471590621, 2], [-1428.629802835527, 1], [-3676.3250099864804, 0]]
# 23714
# fitness_estimate [[0.12632993675913926, 0.005123571934544735, 24.321731684766327], -80.85129004852053]
# fitness_err [0.1574391, 2.183994, 61.12111]
#
# Model ordered by Loglikelihood [[-74.24135502142681, 2], [-75.23250405202702, 3], [-1136.2551610644955, 1], [-4698.872522205578, 0]]
# 241013
# fitness_estimate [[0.10521190705471417, 0, 8.412465100020233], -74.24135502142681]
# fitness_err [0.00023918111, 0, 1.6598127e-06]
#
# Model ordered by Loglikelihood [[-73.99066126355241, 3], [-76.49160138369903, 2], [-953.3549611319237, 1], [-5004.5336707933, 0]]
# 401853
# fitness_estimate [[0.10358814768406685, 0.0012578617713905624, 8.000001004652145], -73.99066126355241]
# fitness_err [0.097511135, 1.8064755, 43.687813]
#
# Model ordered by Loglikelihood [[-72.54318505433831, 3], [-75.32648914393084, 2], [-1519.2537600333033, 1], [-4109.2814896183245, 0]]
# 236402
# fitness_estimate [[0.13295388271308933, -0.0076157714991191994, 20.919916551471058], -72.54318505433831]
# fitness_err [0.12754267, 2.437102, 51.091076]
#
# Model ordered by Loglikelihood [[-78.55881401007602, 3], [-94.04255717573156, 2], [-660.3122240423522, 1], [-5733.682440078503, 0]]
# 354383
# fitness_estimate [[0.0761966857084425, 0.018610786511634128, 3.0770544982447983], -78.55881401007602]
# fitness_err [8.161303e-05, 0.00011280613, 3.4289221e-06]
#
# Model ordered by Loglikelihood [[-70.51556534093052, 2], [-73.2685799476647, 3], [-1026.0442837494172, 1], [-4901.0827601878555, 0]]
# 432887
# fitness_estimate [[0.10615571520866224, 0, 9.643678745947515], -70.51556534093052]
# fitness_err [0.00024741323, 0, 1.6632855e-06]
#
# Model ordered by Loglikelihood [[-76.88386747896922, 3], [-80.76378927278125, 2], [-1149.4915746851236, 1], [-4220.334240035187, 0]]
# 320298
# fitness_estimate [[0.11038400487303576, 0.013618747738501328, 21.344612277258484], -76.88386747896922]
# fitness_err [0.0001166841, 0.00014879594, 5.0736217e-06]
#
# Model ordered by Loglikelihood [[-72.03362236438979, 3], [-73.9179201646089, 2], [-1114.4282233266044, 1], [-4484.558824789618, 0]]
# 380917
# fitness_estimate [[0.1164684467477481, 0.006471545749114788, 20.168895653734207], -72.03362236438979]
# fitness_err [0.00012320423, 0.00014556623, 7.4159907e-06]
#
# Model ordered by Loglikelihood [[-73.97094685091777, 2], [-75.77325094677238, 3], [-1286.8588254399224, 1], [-4159.209965880741, 0]]
# 390472
# fitness_estimate [[0.11055827276372736, 0, 12.624696560821409], -73.97094685091777]
# fitness_err [0.000261827, 0, 1.8080405e-06]
#
# Model ordered by Loglikelihood [[-69.81399144888655, 2], [-77.61382209529157, 3], [-1385.9239063680418, 1], [-3924.439951963478, 0]]
# 127416
# fitness_estimate [[0.12209893774691663, 0, 19.724580863968164], -69.81399144888655]
# fitness_err [0.00029699612, 0, 2.0279335e-06]
#
# Model ordered by Loglikelihood [[-73.49403254036424, 3], [-74.27617120584198, 2], [-1430.3569228243127, 1], [-4032.4113250744917, 0]]
# 240675
# fitness_estimate [[0.1319279721708853, -0.008785328280038314, 19.00000387473532], -73.49403254036424]
# fitness_err [0.17935368, 3.4913073, 73.48876]
#
# Model ordered by Loglikelihood [[-82.87481999076046, 3], [-95.8791416162863, 2], [-792.2112501614754, 1], [-5659.4505698734765, 0]]
# 277427
# fitness_estimate [[0.08453298412101776, 0.010836877992935243, 1.7589115282837362], -82.87481999076046]
# fitness_err [0.18736629, 2.9379308, 92.99074]
#
# Model ordered by Loglikelihood [[-71.94972698423648, 2], [-78.79474785587112, 3], [-1104.802076809639, 1], [-4624.891422406621, 0]]
# 489452
# fitness_estimate [[0.10085350411927273, 0, 5.8448882669929905], -71.94972698423648]
# fitness_err [0.00023107816, 0, 1.6153203e-06]
#
# Model ordered by Loglikelihood [[-68.3453439136325, 2], [-70.85585825801682, 3], [-1227.122730069417, 1], [-4301.373851348342, 0]]
# 291067
# fitness_estimate [[0.12382081644706427, 0, 20.43136241655879], -68.3453439136325]
# fitness_err [0.00030127476, 0, 2.0450584e-06]
#
# Model ordered by Loglikelihood [[-70.41911961382279, 2], [-76.41318367235054, 3], [-872.6855827737414, 1], [-5340.871196615498, 0]]
# 322896
# fitness_estimate [[0.09982560069394356, 0, 4.812526901070544], -70.41911961382279]
# fitness_err [0.00022299576, 0, 1.5551572e-06]
#
# Model ordered by Loglikelihood [[-74.76137933501884, 2], [-77.03747985008711, 3], [-1320.3684531783065, 1], [-4199.949873699095, 0]]
# 248983
# fitness_estimate [[0.11695012150156289, 0, 16.09518554089012], -74.76137933501884]
# fitness_err [0.00027944843, 0, 1.9100241e-06]
#
# Model ordered by Loglikelihood [[-72.72229806573972, 2], [-75.12562106137018, 3], [-868.1226846852553, 1], [-5339.05362114844, 0]]
# 231210
# fitness_estimate [[0.09503887400240026, 0, 0.037097777828210915], -72.72229806573972]
# fitness_err [0.00020965832, 0, 1.4841182e-06]
#
# Model ordered by Loglikelihood [[-77.99585004918247, 2], [-78.14481439917283, 3], [-1147.3609776376409, 1], [-4185.400352479956, 0]]
# 60089
# fitness_estimate [[0.12554735091071023, 0, 21.506100654445447], -77.99585004918247]
# fitness_err [0.00031018775, 0, 2.118583e-06]
#
# Model ordered by Loglikelihood [[-74.33833812466838, 2], [-74.36526256483072, 3], [-1379.1937130435074, 1], [-4119.370717766466, 0]]
# 147822
# fitness_estimate [[0.11535646013130885, 0, 15.73164360525801], -74.33833812466838]
# fitness_err [0.00027563467, 0, 1.8954732e-06]
#
# Model ordered by Loglikelihood [[-74.59076021508874, 2], [-86.12882936274207, 3], [-1071.6319367577628, 1], [-4760.095332395538, 0]]
# 404201
# fitness_estimate [[0.10054810979233006, 0, 5.63062828632775], -74.59076021508874]
# fitness_err [0.00023283236, 0, 1.6256334e-06]
#
# Model ordered by Loglikelihood [[-71.55047011732266, 2], [-74.97830103141239, 3], [-1471.5855411602492, 1], [-3866.58777466492, 0]]
# 119786
# fitness_estimate [[0.12041486271868332, 0, 18.496202558916877], -71.55047011732266]
# fitness_err [0.00028928794, 0, 2.035264e-06]
#
# Model ordered by Loglikelihood [[-72.84321286986764, 2], [-73.4926293596477, 3], [-1177.3788144452421, 1], [-4540.827935539396, 0]]
# 169998
# fitness_estimate [[0.11385170282373507, 0, 14.476708638939492], -72.84321286986764]
# fitness_err [0.00026674278, 0, 1.8256701e-06]
#
# Model ordered by Loglikelihood [[-75.15814472634308, 2], [-77.43957957013676, 3], [-1384.574949626746, 1], [-4134.687396244093, 0]]
# 482322
# fitness_estimate [[0.11364106569312761, 0, 14.317581365313405], -75.15814472634308]
# fitness_err [0.00027001955, 0, 1.8622454e-06]
#
# Model ordered by Loglikelihood [[-76.1132056473064, 3], [-81.48043823652918, 2], [-1646.6514225784033, 1], [-3472.2156651637047, 0]]
# 3685
# fitness_estimate [[0.134154722157174, -0.010961742355478792, 19.36838121756548], -76.1132056473064]
# fitness_err [0.00012071044, 0.00014139483, 7.3440347e-06]
#
# Model ordered by Loglikelihood [[-75.61107761998713, 3], [-77.34757957273202, 2], [-512.4204242471214, 1], [-6239.91925487553, 0]]
# 354339
# fitness_estimate [[0.07840577118843217, 0.015644638604571232, 1.3869994800678351], -75.61107761998713]
# fitness_err [8.195437e-05, 0.000102629696, 4.1775033e-06]
#
# Model ordered by Loglikelihood [[-73.24656576402312, 2], [-74.30774584333696, 3], [-962.894943899548, 1], [-4912.981096029808, 0]]
# 24552
# fitness_estimate [[0.09927826394399814, 0, 4.037518679387025], -73.24656576402312]
# fitness_err [0.00022974267, 0, 1.5544427e-06]
#
# Model ordered by Loglikelihood [[-68.62138364834685, 2], [-80.72314995058187, 3], [-1394.7894569621492, 1], [-3812.284255928067, 0]]
# 128537
# fitness_estimate [[0.12162233272901168, 0, 19.697980545402004], -68.62138364834685]
# fitness_err [0.00030103902, 0, 2.0548246e-06]
#
# Model ordered by Loglikelihood [[-72.42890290007085, 3], [-75.28944039948165, 2], [-1545.6031409419593, 1], [-4007.042196691266, 0]]
# 54079
# fitness_estimate [[0.1416279882263091, -0.020891409324039982, 17.99343743757466], -72.42890290007085]
# fitness_err [0.19477089, 4.8460674, 83.173874]
#
# Model ordered by Loglikelihood [[-74.25662328205544, 2], [-75.27839544340426, 3], [-779.5012110568119, 1], [-5223.248028722725, 0]]
# 196872
# fitness_estimate [[0.09467754188859367, 0, 0.7189047538259616], -74.25662328205544]
# fitness_err [0.00021267206, 0, 1.5041185e-06]
#
# Model ordered by Loglikelihood [[-70.36787683523954, 2], [-73.45436598843679, 3], [-1089.6383646460488, 1], [-4633.28047320311, 0]]
# 341446
# fitness_estimate [[0.11545553128354542, 0, 15.628646782782454], -70.36787683523954]
# fitness_err [0.00027177975, 0, 1.8573629e-06]
#
# Model ordered by Loglikelihood [[-72.15589463320154, 2], [-77.3677822192184, 3], [-1269.129019735003, 1], [-3901.7375401743493, 0]]
# 10710
# fitness_estimate [[0.11313737891185677, 0, 14.49808236877763], -72.15589463320154]
# fitness_err [0.00027780383, 0, 1.9166762e-06]
#
# Model ordered by Loglikelihood [[-68.59098506471273, 2], [-69.98036047469824, 3], [-826.7980113920285, 1], [-5081.609892579343, 0]]
# 387475
# fitness_estimate [[0.11200414689999216, 0, 13.997768739584302], -68.59098506471273]
# fitness_err [0.00026417893, 0, 1.7858287e-06]
#
# Model ordered by Loglikelihood [[-67.34051267750368, 2], [-72.93976256865685, 3], [-868.6110666761746, 1], [-4775.688675725622, 0]]
# 80625
# fitness_estimate [[0.11512166197142021, 0, 15.014392561875468], -67.34051267750368]
# fitness_err [0.00027184852, 0, 1.9829636e-06]
#
# Model ordered by Loglikelihood [[-72.17562994300555, 2], [-78.32300963639186, 3], [-868.2548542169567, 1], [-5344.247210489181, 0]]
# 238544
# fitness_estimate [[0.09705835877012908, 0, 2.7178540612054487], -72.17562994300555]
# fitness_err [0.0002194233, 0, 1.4973531e-06]
#
# Model ordered by Loglikelihood [[-74.87084324727724, 3], [-83.77739664386242, 2], [-1011.8910237631268, 1], [-4530.954024219087, 0]]
# 85250
# fitness_estimate [[0.10039804948394508, 0.012679392671813627, 15.574609112815551], -74.87084324727724]
# fitness_err [0.00010925556, 0.00013472563, 5.531586e-06]
#
# Model ordered by Loglikelihood [[-72.15399724697278, 2], [-73.2389227432412, 3], [-786.8986454395966, 1], [-5201.547542301733, 0]]
# 359964
# fitness_estimate [[0.09475651272549684, 0, 3.222126965551431e-05], -72.15399724697278]
# fitness_err [0.00021062822, 0, 1.5371311e-06]
#
# Model ordered by Loglikelihood [[-76.83450491898856, 3], [-76.98632837689773, 2], [-1176.2676564294466, 1], [-4028.81864376334, 0]]
# 378495
# fitness_estimate [[0.10195340875022066, 0.007126642606300273, 12.404984853699755], -76.83450491898856]
# fitness_err [0.08671968, 1.3793488, 40.508633]
#
# Model ordered by Loglikelihood [[-66.20912557688665, 2], [-68.93329256337903, 3], [-582.1786543139664, 1], [-5431.770741566124, 0]]
# 296038
# fitness_estimate [[0.10442129784082084, 0, 8.354393039187737], -66.20912557688665]
# fitness_err [0.00024372785, 0, 1.68274e-06]
#
# Model ordered by Loglikelihood [[-70.54953798166969, 3], [-70.76075451239981, 2], [-941.5566398270248, 1], [-4633.170109922271, 0]]
# 424504
# fitness_estimate [[0.1054708634351452, 0.012747590994270206, 18.54171528528976], -70.54953798166969]
# fitness_err [0.00011655388, 0.00014236405, 6.0698344e-06]
#
# Model ordered by Loglikelihood [[-75.30317304499835, 3], [-76.22011987813798, 2], [-1536.0983767976177, 1], [-3683.5469193332187, 0]]
# 178552
# fitness_estimate [[0.13445836430588592, -0.015052583918931309, 17.40403324391374], -75.30317304499835]
# fitness_err [0.06289991, 1.3084103, 25.193232]
#
# Model ordered by Loglikelihood [[-74.74102202630752, 3], [-76.32585857826963, 2], [-1135.4005748872498, 1], [-4001.4239709286758, 0]]
# 430801
# fitness_estimate [[0.1191949031647391, 0.01045370344356583, 24.999998881035687], -74.74102202630752]
# fitness_err [0.10442879, 1.3266995, 38.111847]
#
# Model ordered by Loglikelihood [[-76.78363844088912, 2], [-77.66148347466714, 3], [-1363.3222427203066, 1], [-3662.3864598316463, 0]]
# 125308
# fitness_estimate [[0.12712034748226775, 0, 22.779538241827467], -76.78363844088912]
# fitness_err [0.00032233546, 0, 2.1988676e-06]
#
# Model ordered by Loglikelihood [[-74.89116969963746, 3], [-75.03618771613351, 2], [-1183.0901107202064, 1], [-4321.774886982946, 0]]
# 309210
# fitness_estimate [[0.14177436179799974, -0.021491830690784496, 17.63122937469397], -74.89116969963746]
# fitness_err [0.052111503, 1.3435248, 22.362461]
#
# Model ordered by Loglikelihood [[-75.14820505798791, 3], [-88.48250942851475, 2], [-919.3935477351234, 1], [-5129.029521036869, 0]]
# 336753
# fitness_estimate [[0.10455203262904154, -0.004454034952105615, 4.842709123461689], -75.14820505798791]
# fitness_err [9.168562e-05, 0.00010690853, 6.300277e-06]
#
# Model ordered by Loglikelihood [[-72.79503297001764, 2], [-73.12062597385938, 3], [-706.1200812100782, 1], [-5332.484583703926, 0]]
# 315146
# fitness_estimate [[0.09773395219796303, 0, 3.9706199925304784], -72.79503297001764]
# fitness_err [0.00022627453, 0, 1.5798191e-06]
#
# Model ordered by Loglikelihood [[-68.91148410067524, 2], [-68.99942701796617, 3], [-1077.163897983493, 1], [-4618.719811938026, 0]]
# 476470
# fitness_estimate [[0.10531956135784522, 0, 9.988378425713925], -68.91148410067524]
# fitness_err [0.00025591694, 0, 1.6796092e-06]
#
# Model ordered by Loglikelihood [[-69.47590778443325, 2], [-72.24663441853596, 3], [-795.2545881979444, 1], [-5449.0312449120565, 0]]
# 366881
# fitness_estimate [[0.09713960344614919, 0, 2.630498094297418], -69.47590778443325]
# fitness_err [0.00021756015, 0, 1.5217471e-06]
#
# Model ordered by Loglikelihood [[-83.18055800641724, 3], [-92.53081255787707, 2], [-620.000261253848, 1], [-5390.44143261596, 0]]
# 427615
# fitness_estimate [[0.07444358901041404, 0.025518143355751872, 8.999998928989577], -83.18055800641724]
# fitness_err [8.9725145e-05, 0.00012434534, 3.2051043e-06]
#
# Model ordered by Loglikelihood [[-73.98954842193652, 3], [-76.42119787483483, 2], [-1062.8773492926364, 1], [-4550.17880691393, 0]]
# 248091
# fitness_estimate [[0.10323297484306401, -0.008100437056197238, 0.8017912133424716], -73.98954842193652]
# fitness_err [0.10918087, 2.3104637, 50.56572]
#
# Model ordered by Loglikelihood [[-72.13648182448294, 3], [-73.94342295938733, 2], [-1318.0401700369805, 1], [-4142.4682826372655, 0]]
# 15836
# fitness_estimate [[0.12138377247193607, -0.008933215675097016, 13.293266527983933], -72.13648182448294]
# fitness_err [0.07112789, 1.442111, 30.439577]
#
# Model ordered by Loglikelihood [[-67.25786403917584, 2], [-77.34804760265331, 3], [-1086.2001658699319, 1], [-4512.857310368406, 0]]
# 408740
# fitness_estimate [[0.11314113005246534, 0, 14.601584643282926], -67.25786403917584]
# fitness_err [0.00027356815, 0, 1.8751939e-06]
#
# Model ordered by Loglikelihood [[-73.95286511308323, 3], [-84.47513157577038, 2], [-431.8974834696793, 1], [-6102.825426297842, 0]]
# 204330
# fitness_estimate [[0.0715284738433072, 0.022972317744294125, 3.4584750749867634], -73.95286511308323]
# fitness_err [0.13642275, 1.7447585, 62.817177]
#
# Model ordered by Loglikelihood [[-75.50984567350798, 3], [-77.9667202882321, 2], [-898.0878466088908, 1], [-4726.783184480436, 0]]
# 154277
# fitness_estimate [[0.1007875131031293, 0.009451961213353687, 13.081234361156332], -75.50984567350798]
# fitness_err [0.09350636, 1.4420112, 39.479424]
#
# Model ordered by Loglikelihood [[-76.77611631934195, 3], [-77.10341160447578, 2], [-1184.8997521021267, 1], [-3994.7580312777645, 0]]
# 11668
# fitness_estimate [[0.123346894811292, 0.008857032159602428, 25.73441801066567], -76.77611631934195]
# fitness_err [0.00013614916, 0.00016366677, 7.2955245e-06]
#
# Model ordered by Loglikelihood [[-70.03809875221891, 2], [-72.48961195250627, 3], [-1202.5376744502498, 1], [-4353.592781026325, 0]]
# 323329
# fitness_estimate [[0.1165263066889713, 0, 16.616726880562226], -70.03809875221891]
# fitness_err [0.00028175782, 0, 1.9064536e-06]
#
# Model ordered by Loglikelihood [[-70.54986881421421, 2], [-73.8307406160007, 3], [-1237.2817639334041, 1], [-3890.1938529254785, 0]]
# 485632
# fitness_estimate [[0.11599189533316899, 0, 16.9874724476696], -70.54986881421421]
# fitness_err [0.00028944504, 0, 1.9755282e-06]
#
# Model ordered by Loglikelihood [[-70.70036822398464, 2], [-73.032130276704, 3], [-764.0317780264758, 1], [-5163.521223639464, 0]]
# 246739
# fitness_estimate [[0.09445515139072529, 0, 0.7754041775043525], -70.70036822398464]
# fitness_err [0.00021385774, 0, 1.5312238e-06]

# %% [markdown]
# When the model is chosen it is saved in a file thanks to the code in the next cell. It follows the same rules as before .

# %%
w=open("/Result_fit/result_fit_choosen.txt",'w')# add address where the chosen model and the error on estimate should be saved
for s in fitness_estimate.keys():
    w.write('>'+str(s)+'\t'+str(fitness_estimate[s][0][0])+'\t'+str(fitness_estimate[s][0][1])+'\t'+str(fitness_estimate[s][0][2])+'\t'+str(fitness_estimate[s][1])+'\n')
    w.write('@'+str(s)+'\t'+str(fitness_err[s][0])+'\t'+str(fitness_err[s][1])+'\t'+str(fitness_err[s][2])+'\n')
w.close()

# %% [markdown]
# # Visualization

# %%
#plots the phase space of your evolution
pylab.rcParams['figure.figsize'] = 5, 5
plt.rc("font", size=23)
word=[s for s in fitness_estimate.keys() if len(fitness_estimate[s][0])==3]

plt.scatter([fitness_estimate[s][0][2] for s in word if fitness_estimate[s][0][1]!=0 and fitness_estimate[s][0][0]!=0 and min(data_dict[s])>0 ],\
            [fitness_estimate[s][0][0]+fitness_estimate[s][0][1] for s in word if fitness_estimate[s][0][1]!=0 and fitness_estimate[s][0][0]!=0 ],c='r',alpha=0.5,label='3 parameters model \n mutants')#here we add the ancestral mutant fitness to the rising mutant as their are relative to each other
plt.scatter([fitness_estimate[s][0][2] for s in word if fitness_estimate[s][0][1]==0 and fitness_estimate[s][0][0]!=0 and min(data_dict[s])>0 ],\
            [fitness_estimate[s][0][0]+fitness_estimate[s][0][1] for s in word if fitness_estimate[s][0][1]==0 and fitness_estimate[s][0][0]!=0 and min(data_dict[s])>0 ],c='g',label='2 parameters model \n mutants')

plt.legend(loc='best',fontsize=10)
plt.tight_layout()
plt.savefig('',bbox_inches='tight')
plt.xlabel('Establishment time (generation)')
plt.ylabel('Fitness per generation')
plt.show()

# %%
#plots the DFE for the selected models
pylab.rcParams['figure.figsize'] = 5, 20
plt.rc("font", size=23)
mi=-0.1
ma=0.2
nnn=np.arange(mi,ma,(ma-mi)/100)
plt.subplot(4,1,1)
print('Fraction of lineages explained by 1 parameter model',len([fitness_estimate[s][0][1] for s in fitness_estimate.keys() if fitness_estimate[s][0][0]==0 and fitness_estimate[s][0][2]==0]\
         )/len(fitness_estimate))
plt.hist(\
    [fitness_estimate[s][0][1] for s in fitness_estimate.keys() if fitness_estimate[s][0][0]==0 and fitness_estimate[s][0][2]==0],color='k',label='1 parameter model',bins=nnn)
plt.title("DFE 1 parameter model")
plt.subplot(4,1,2)
print('Fraction of lineages explained by 2 parameters model',len([fitness_estimate[s][0][0] for s in fitness_estimate.keys() if fitness_estimate[s][0][1]==0 and fitness_estimate[s][0][2]!=0]\
         )/len(fitness_estimate))
plt.hist(\
    [fitness_estimate[s][0][0] for s in fitness_estimate.keys() if fitness_estimate[s][0][1]==0 and fitness_estimate[s][0][2]!=0],color='g',label='2 parameters model',bins=nnn)
plt.title("DFE 2 parameters model : emerging mutant")
plt.subplot(4,1,3)
print('Fraction of lineages explained by 3 parameters model',len([fitness_estimate[s][0][1]+fitness_estimate[s][0][0] for s in fitness_estimate.keys() if fitness_estimate[s][0][0]!=0 and fitness_estimate[s][0][2]!=0 and fitness_estimate[s][0][1]!=0]\
         )/len(fitness_estimate))
plt.hist(\
    [fitness_estimate[s][0][1]+fitness_estimate[s][0][0] for s in fitness_estimate.keys() if fitness_estimate[s][0][0]!=0 and fitness_estimate[s][0][2]!=0 and fitness_estimate[s][0][1]!=0],color='r',label='3 parameters model : mutant',bins=nnn)
plt.title("DFE 3 parameters model : emerging mutant")
plt.subplot(4,1,4)
plt.hist(\
    [fitness_estimate[s][0][1] for s in fitness_estimate.keys() if fitness_estimate[s][0][0]!=0 and fitness_estimate[s][0][2]!=0 and fitness_estimate[s][0][1]!=0],color='lightcoral',label='3 parameters model : original',bins=nnn)
plt.title("DFE 3 parameters model : initial mutant")
plt.tight_layout()
plt.savefig('',bbox_inches='tight')
plt.show()
# Out:
# Fraction of lineages explained by 1 parameter model 0.002
# Fraction of lineages explained by 2 parameters model 0.593
# Fraction of lineages explained by 3 parameters model 0.405

# %% [markdown]
# # Initial mix of mutants model : optional

# %% [markdown]
# Give you the option to add one more model if you are dissatisfied with too negative establishment time: this model postulate that there is actually already two mutants in the lineage at the beginning of the environment. The model estimates the frequency of those two mutants in the lineage as well as their fitnesses. The fitness of the less abundant mutant is relative to the more abundant one (i.e. the more abundant mutant fitness should be added to the less abundant one). fitness_estimate1111[BC]=(s less abundant, s more abundant, frequency of less abundant).!

# %%
s_0=smooth_fitness[0]

stop=0
def neutral_hypothesis_probability2(r_t,totit,totitT,r_tT,smoothie,kappa,s1,x):
    
    ending=int(sum([generation[i] for i in range(x)]))
    zumo=int(generation[x])
    
    T_s_bar=sum([s1-smoothie[i] for i in range(ending+zumo)])
    
    result=np.log(np.sqrt((float(r_t*totitT)/totit*np.exp(T_s_bar))**(1./2)/\
                                       (4*math.pi*kappa*(float(r_tT)**(3./2)))))\
    -((np.sqrt(float(r_tT))-np.sqrt(float(r_t*totitT)/totit*np.exp(T_s_bar)))**2)/kappa
    
    return result

def log_likelihood_neutral_hypothesis2(data,s1):
    aa=list()
    for i in range(len(timepoint)-1-stop):
        
        aa.append(neutral_hypothesis_probability1(data[0],tot_pop[0],tot_pop[i+1],data[i+1],smooth_fitness,mean_kappa[i],s1,i))
    
    aa.append(np.log(np.sqrt((data[0])**(1./2)/(4*math.pi*2*(data[0])**(3./2))))\
                         -(np.sqrt(data[0])-np.sqrt(data[0]))**2/2)
    log_like=sum(aa)
    
    return log_like

        
        
def adaptive_hypothesis_probability2(key,r_t,r_tT,smoothie,x,kappa,s,s1,tau,Rt,ouft,ouftT):
    
    found=True
    ending=int(sum([generation[i] for i in range(x)]))
    zumo=int(generation[x])
    N=data_dict[key][0]/tot_pop[0]*N_e
    if found==True:
        
        s_anc=0
        s_mut=s
        
        
        
        
            
        delta=1
        x_f=[tau]
        s_bar=[x_f[0]*(s_mut-s_anc)+s_anc]
        for i in range (1,ending+zumo):
            x_f.append(x_f[i-1]*np.exp((s_mut-s_bar[i-1])*delta))
            s_bar.append(x_f[i]*(s_mut-s_anc)+s_anc)    
        
        T_s=sum([s for i in range(ending,ending+zumo)])
        T_s0=sum([s1-smoothie[i] for i in range(ending,ending+zumo)])
        
        if tau>=0:
            T_s_0=sum([s_bar[i]+s1-smoothie[i] for i in range(ending)])
            
        
        New_tot=N*Rt*np.exp(T_s_0)/(N_e)
        x_f[ending]*=New_tot
        
        mean_r_tT=((x_f[ending])*np.exp(T_s)+\
                       (New_tot-x_f[ending]))*np.exp(T_s0)
        
        result=np.log(np.sqrt((mean_r_tT*ouftT/ouft)**(1./2)/(4*math.pi*kappa*(r_tT)**(3./2))))\
            -(np.sqrt(r_tT)-np.sqrt(mean_r_tT*ouftT/ouft))**2/kappa
        
            
    else:
        
        result=neutral_hypothesis_probability1(data_dict[key][0],tot_pop[0],ouftT,r_tT,smooth_fitness,kappa,s1,x)
        
    return result







def log_likelihood_adaptive_hypothesis2(key,data,s,s1,tau):
    
                
    log_like=sum([adaptive_hypothesis_probability2(key,data[i],data[i+1],smooth_fitness,i,mean_kappa[i],\
                                                         s,s1,tau,R_t[i],tot_pop[i],tot_pop[i+1])for i in range(len(timepoint)-1-stop)\
                 ])
    
    
    found=True
    if found==True :
        
        s_anc=0
        s_mut=s
        
        
        
        
        T_s=(s)
        T_s0=(s1-s_0)
        if (tau)<=1:
            mean_r_tT=((tau)*data[0]*np.exp(T_s)+(data[0]-((1-tau)*data[0])))*np.exp(T_s0)
        else:
            mean_r_tT=((tau)*data[0]*np.exp(T_s))*np.exp(T_s0)
        
    else:
        mean_r_tT=data[0]
        
        
    log_like+=np.log(np.sqrt((mean_r_tT)**(1./2)\
                                 /(4*math.pi*2*(data[0])**(3./2))))\
                                -(np.sqrt(data[0])-np.sqrt(mean_r_tT))**2/2#-np.log(np.sqrt(data[0]*math.pi*2))
    
    return log_like

# %%
def model1111(x,key,data):
    s=x[0]
    s1=x[1]
    tau=x[2]
    
    return -(np.log(1./mean_exp*np.exp(-1./mean_exp*(2*s1+s))*mut_rate**2*delta_s**3))
fitness_estimate1111={}
fitness_estimate1111_err={}
ranges=[[0.01,0.2],[-0.1,0.2],[0,0.4]]


for s in vr111:
    
    
    argumentes=[[0,fitness_estimate010[s][0][1],0],s,data_dict[s]]
    pro_list=[]
    manager = multiprocessing.Manager()
    mouff = manager.dict()
    for i in range(10):
        p = Process(target=Nelder_Mead3_list, args=(i,mouff,model1111,argumentes,1,0.5,2,0.5,ranges,10**-6,100))
        pro_list.append(p)


    for p in pro_list:
        p.start()

    for p in pro_list:
        p.join()
    
       
    [estimate,fval]=sorted(mouff.values(),key=itemgetter(1))[0]
    fitness_estimate1111[s]=[estimate,-fval]
    print('Log likelihood',-fval)
    print('Estimates',estimate)
    fitness_estimate1111_err[s]=['nan','nan','nan']
    
    try:
        Jout=[[model1111([estimate[0]+i*0.01,estimate[1],estimate[2]],s,data_dict[s]) for i in range(-1,2,1)]\
              ,[model1111([estimate[0],estimate[1]+i*0.01,estimate[2]],s,data_dict[s]) for i in range(-1,2,1)]\
          ,[model1111([estimate[0],estimate[1],estimate[2]+i*0.01],s,data_dict[s]) for i in range(-1,2,1)]]
        h=hessian(np.array(Jout),[0.01,0.01,0.01])#[:,:,1,2]
        
        print('hessian Mix',h)
        

        err1=h[0][0]
        err2=h[1][1]
        err3=h[2][2]
        #fitness_estimate1111_err[s]=[1./np.sqrt(err1/it),1./np.sqrt(err2/it),1./np.sqrt(err3/it)]
        fitness_estimate1111_err[s]=[np.sqrt(err1*it),np.sqrt(err2*it),np.sqrt(err3*it)]
        print('SD Mix initial model',fitness_estimate1111_err[s])
        print()
    except:
        print('Invalid Hessian')

# %% [markdown]
# # Analysis accuracy : example

# %%
f=open("/Result_simu/"+'_0.263715230039_0.167713341389_1_final.txt','r')#you don't have that file....
lignes=f.readlines()
list_o=list()
real_adaptive=dict()
real_adaptive1=dict()
pop_real_adaptive=dict()
freq_bene=dict()
freq_lineage=dict()
pop_pop_real_adaptive=dict()
one_BC='0'
len_dic={}
mean_fit_mut={}
for i in range(len(lignes)):
    if lignes[i][0]=='@':
        one_BC+=1
        pop_str=lignes[i+1].split('\t')
        fit_str=lignes[i+2].split('\t')
        tau_str=lignes[i+3].split('\t')
        
        sort_all=sorted([[float(pop_str[p])\
                      ,float(fit_str[p]),float(tau_str[p])]for p in range(len(tau_str)-1)],\
                    key=itemgetter(0),reverse=True)[0:2]
        if str(one_BC) in fitness_estimate.keys():
            len_dic[one_BC]=len([pop_str[h] for h in range(len(pop_str)-1) if float(pop_str[h])>0])
        
        
        if sort_all[0][0]>0:
            if len(sort_all)>1:
                mino=sorted(sort_all,key=itemgetter(2),reverse=True)
                
                
                if mino[0][2]>0 and mino[1][2]==0:
                    real_adaptive[str(one_BC)]=[mino[0][1],mino[0][2],mino[0][0]]
                    real_adaptive1[str(one_BC)]=[mino[1][1],mino[1][2],mino[1][0]]
                    pop_pop_real_adaptive[str(one_BC)]=[[mino[0][0],mino[0][1],mino[0][2]],[mino[1][0],mino[1][1],mino[1][2]]]
                
            else:
                if sort_all[0][2]>0:
                    real_adaptive[str(one_BC)]=[sort_all[0][1],sort_all[0][2]]
                else:
                    real_adaptive1[str(one_BC)]=[sort_all[0][1],sort_all[0][2]]

# %%
fitness_estimate_str={str(s):fitness_estimate[s] for s in fitness_estimate.keys()}

# %%
pylab.rcParams['figure.figsize'] = 5, 5
plt.rc("font", size=23)
mp=200
fino=[s for s in real_adaptive.keys()&real_adaptive1.keys()&fitness_estimate_str.keys()]
plt.plot([fitness_estimate_str[s][0][1] for s in fino if real_adaptive[s][1]<mp and fitness_estimate_str[s][0][1]!=0 and fitness_estimate_str[s][0][0]!=0],\
         [real_adaptive1[s][0] for s in fino if real_adaptive[s][1]<mp and fitness_estimate_str[s][0][1]!=0 and fitness_estimate_str[s][0][0]!=0],'r+',markersize=10,label='3 parameters model : original')
plt.legend(loc='best',fontsize=10)
plt.plot([0.02,0.13],[0.02,0.13],'k--')
plt.xlabel("Estimated")
plt.ylabel("True")

plt.show()
plt.plot([fitness_estimate_str[s][0][1]+fitness_estimate_str[s][0][0] for s in fino if real_adaptive[s][1]<mp and fitness_estimate_str[s][0][1]!=0 and fitness_estimate_str[s][0][0]!=0],\
         [real_adaptive[s][0] for s in fino if real_adaptive[s][1]<mp and fitness_estimate_str[s][0][1]!=0 and fitness_estimate_str[s][0][0]!=0],'ro',label='3 parameters model : mutant')
plt.legend(loc='best',fontsize=10)
plt.plot([0.02,0.25],[0.02,0.25],'k--')
plt.xlabel("Estimated")
plt.ylabel("True")
plt.show()

# %%
pylab.rcParams['figure.figsize'] = 5, 5
plt.rc("font", size=23)
fino=[s for s in real_adaptive.keys()&real_adaptive1.keys()&fitness_estimate_str.keys() if fitness_estimate_str[s][0][1]!=0 and fitness_estimate_str[s][0][0]==0]

print(len(fino))
plt.plot([fitness_estimate_str[s][0][1] for s in fino ],[real_adaptive1[s][0] for s in fino ],'ko',label='1 parameter model')

plt.tight_layout()
plt.plot([0.02,0.13],[0.02,0.13],'k--')
plt.legend(loc='best',fontsize=10)
plt.xlabel("Estimated")
plt.ylabel("True")
plt.show()
# Out:
# 2

# %%
pylab.rcParams['figure.figsize'] = 5, 5
plt.rc("font", size=23)
fino=[s for s in real_adaptive.keys()&real_adaptive1.keys()&fitness_estimate_str.keys() if fitness_estimate_str[s][0][1]==0 and fitness_estimate_str[s][0][0]!=0]

plt.plot([fitness_estimate_str[s][0][0] for s in fino ],[real_adaptive[s][0] for s in fino ],'go',label='2 parameters model :mutant')
plt.plot([0.02,0.13],[0.02,0.13],'k--')
plt.legend(loc='best',fontsize=10)
plt.xlabel("Estimated")
plt.ylabel("True")
plt.tight_layout()

plt.show()
plt.plot([fitness_estimate_str[s][0][1] for s in fino ],[real_adaptive1[s][0] for s in fino ],'g+',markersize=10,label='2 parameters model : original')
plt.legend(loc='best',fontsize=10)
plt.xlabel("Estimated")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# %%
from IPython.display import Image

# %%
Image(filename=)

# %% [markdown]
# $\textbf{Simulation used to check analysis}$

# %%
Image(filename=)

# %% [markdown]
# $\textbf{Comparison between estimated fitness from different chosen best model by the code and their real value.}$ Analysis makes good model prediction and good range of value prediction.
