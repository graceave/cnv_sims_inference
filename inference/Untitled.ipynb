# %%
# !python -W ignore ./infer_rejectionABC.py -m "Chemo" -obs "Chemo_simulated_single_observations.csv" -pd "Chemo_presimulated_data_100000_2.csv" -pt "Chemo_presimulated_theta_100000_2.csv" -d "./" -s 1 -g "generations.csv" -o "Chemo_rejectionABC_100000_2"
# Out:
# Optimization terminated successfully.
#          Current function value: -0.679549
#          Iterations: 29
#          Function evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.679616
#          Iterations: 28
#          Function evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.679612
#          Iterations: 26
#          Function evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.679485
#          Iterations: 28
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.679497
#          Iterations: 28
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.672357
#          Iterations: 33
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: -0.672303
#          Iterations: 28
# ...
